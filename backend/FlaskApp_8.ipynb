# %%
from app import app, db, bcrypt
from models import User, Stock, Portfolio
from flask import jsonify, request
import pandas as pd
import sqlite3

# %%
data = [
  {
    "date": "Sat, 01 Mar 2025 00:00:00 GMT",
    "id": 2,
    "purchase_price": 1600.0,
    "quantity": 10,
    "symbol": "HDFCBANK.NS"
  },
  {
    "date": "Sat, 01 Feb 2025 00:00:00 GMT",
    "id": 3,
    "purchase_price": 2200.0,
    "quantity": 20,
    "symbol": "HINDUNILVR.NS"
  },
  {
    "date": "Tue, 04 Mar 2025 00:00:00 GMT",
    "id": 4,
    "purchase_price": 3500.0,
    "quantity": 30,
    "symbol": "TCS.NS"
  },
  {
    "date": "Fri, 04 Aug 2023 00:00:00 GMT",
    "id": 5,
    "purchase_price": 900.0,
    "quantity": 10,
    "symbol": "BBTC.NS"
  },
  {
    "date": "Sat, 01 Feb 2025 00:00:00 GMT",
    "id": 6,
    "purchase_price": 1200.0,
    "quantity": 20,
    "symbol": "BALKRISIND.NS"
  },
  {
    "date": "Tue, 10 Sep 2019 00:00:00 GMT",
    "id": 12,
    "purchase_price": 1400.0,
    "quantity": 90,
    "symbol": "HDFCBANK.NS"
  },
  {
    "date": "Wed, 19 May 2021 00:00:00 GMT",
    "id": 13,
    "purchase_price": 1500.0,
    "quantity": 30,
    "symbol": "HDFCBANK.NS"
  },
  {
    "date": "Wed, 08 Feb 2023 00:00:00 GMT",
    "id": 14,
    "purchase_price": 1450.0,
    "quantity": 70,
    "symbol": "HDFCBANK.NS"
  },
  {
    "date": "Wed, 08 Feb 2023 00:00:00 GMT",
    "id": 15,
    "purchase_price": 2450.0,
    "quantity": 70,
    "symbol": "HINDUNILVR.NS"
  },
  {
    "date": "Thu, 11 Mar 2021 00:00:00 GMT",
    "id": 16,
    "purchase_price": 2150.0,
    "quantity": 90,
    "symbol": "HINDUNILVR.NS"
  },
  {
    "date": "Wed, 10 Jul 2019 00:00:00 GMT",
    "id": 17,
    "purchase_price": 3000.0,
    "quantity": 60,
    "symbol": "TCS.NS"
  },
  {
    "date": "Tue, 11 Mar 2025 00:00:00 GMT",
    "id": 18,
    "purchase_price": 1400.0,
    "quantity": 40,
    "symbol": "BALKRISIND.NS"
  },
  {
    "date": "Tue, 11 Mar 2025 00:00:00 GMT",
    "id": 19,
    "purchase_price": 1400.0,
    "quantity": 40,
    "symbol": "BALKRISIND.NS"
  }
]

# %%
import sys
import json
import sqlite3
from datetime import datetime, date, timedelta

#data_input = sys.argv[1]

# start and end date
startDate = date.today() - timedelta(days=365)
endDate = date.today()

# Factory Pattern for Trade Creation
class Trade:
    def __init__(self, id, symbol, purchase_price, quantity, date):
        self.id = id
        self.symbol = symbol
        self.purchase_price = purchase_price
        self.quantity = quantity
        self.date = datetime.strptime(date, '%a, %d %b %Y %H:%M:%S %Z')

    def __str__(self):
        return f"Trade(symbol={self.symbol}, purchase_price={self.purchase_price})"

    def lastPrice(self):
        return PortfolioValueProvider().get_asset_value(self.symbol,"Close", startDate, endDate)

    def totalValueNew(self):
        return self.quantity * self.lastPrice()


class TradeFactory:
    def create_trade(self, id, symbol, purchase_price, quantity, date):
        return Trade(id, symbol, purchase_price, quantity, date)


# Portfolio Class with Aggregation and API Interaction
class Portfolio:
    def __init__(self):
        self.trades = []
        self.value_provider = PortfolioValueProvider()
        self.net_values = None  # Store the calculated net values
        self.portfolio_status = {}  # Store the portfolio's status for each date

    def add_trade(self, trade):
        self.trades.append(trade)
        self.update_portfolio_status()

    def add_trades(self, trade_data):
        trade_factory = TradeFactory()
        for trade_info in trade_data:
            self.trades.append(trade_factory.create_trade(**trade_info))
        self.update_portfolio_status()

    def calculate_net(self):
        if self.net_values is None:
            net_value = {}
            total_quantity = {}
            average_price = {}
            current_value = {}
            for trade in self.trades:
                if trade.symbol in net_value:
                    net_value[trade.symbol] += trade.quantity * trade.purchase_price
                    total_quantity[trade.symbol] += trade.quantity
                    average_price[trade.symbol] = net_value[trade.symbol] / total_quantity[trade.symbol]
                    current_value[trade.symbol] = total_quantity[trade.symbol] * self.value_provider.get_asset_value(
                        trade.symbol, "Close", startDate, endDate)
                else:
                    net_value[trade.symbol] = trade.quantity * trade.purchase_price
                    total_quantity[trade.symbol] = trade.quantity
                    average_price[trade.symbol] = net_value[trade.symbol] / total_quantity[trade.symbol]
                    current_value[trade.symbol] = total_quantity[trade.symbol] * self.value_provider.get_asset_value(
                        trade.symbol, "Close", startDate, endDate)
            self.net_values = net_value, total_quantity, average_price, current_value

        return self.net_values

    def calculate_current_value(self, currency):
        current_value = {}
        for trade in self.trades:
            currency_converter = 1
            asset_value = self.value_provider.get_asset_value(trade.symbol, "Close", startDate, trade.date)
            if asset_value is not None:
                current_value[trade.symbol] = asset_value * trade.quantity * currency_converter
        return current_value

    def update_portfolio_status(self):
        for trade in self.trades:
            if trade.date not in self.portfolio_status:
                self.portfolio_status[trade.date] = {}

            if trade.symbol not in self.portfolio_status[trade.date]:
                self.portfolio_status[trade.date][trade.symbol] = trade.quantity
            else:
                self.portfolio_status[trade.date][trade.symbol] += trade.quantity

    def get_portfolio_status_by_date(self, date):
        return self.portfolio_status.get(date, {})

    def get_portfolio_status_for_dates(self, dates):
        portfolio_status_for_dates = []

        for date in dates:
            portfolio_status_for_dates.append({
                'date': date,
                'assets_quantity': self.get_portfolio_status_by_date(date)
            })

        return portfolio_status_for_dates

    def calculate_daily_values_oneyear(self, currency):
        daily_values = []
        trade_dates = []
        stock_quantity = {}
        start_dt = startDate
        end_dt = endDate
        delta = timedelta(days=1)

        # store the dates between two dates in a list
        dates_oneyear = []

        while start_dt <= end_dt:
            dates_oneyear.append(start_dt.isoformat())
            start_dt += delta

        sorted_trades = sorted(self.trades, key=lambda trade: trade.date)
        for date in dates_oneyear:
            total_value_for_date = 0
            for trade in sorted_trades:
                if trade.date == date:
                    total_value_for_date += trade.quantity * self.value_provider.get_asset_value(trade.symbol, date)
            daily_values.append(total_value_for_date)

        portfolio_status = self.get_portfolio_status_for_dates(dates_oneyear)

        return portfolio_status, dates_oneyear

    def assets_on_dates_oneyear(self):
        dates_oneyear = []
        start_dt = startDate
        end_dt = endDate
        delta = timedelta(days=1)

        while start_dt <= end_dt:
            dates_oneyear.append(start_dt.isoformat())
            start_dt += delta

        assets_by_date = {}

        trade_dates_set = set(trade.date for trade in self.trades)
        sorted_trades = sorted(self.trades, key=lambda trade: trade.date)

        for date1 in dates_oneyear:
            assets_on_date = {}
            date1_dt = datetime.fromisoformat(date1)  # Convert date1 to datetime object
            for trade in self.trades:
                if trade.date <= date1_dt:
                    if trade.symbol in assets_on_date:
                        assets_on_date[trade.symbol] += trade.quantity
                    else:
                        assets_on_date[trade.symbol] = trade.quantity
            assets_by_date[date1] = assets_on_date

        return assets_by_date

    @staticmethod
    def portfolio_value_for_dates(portfolio_dict, currency):
        stock_data = {}
        value_provider = PortfolioValueProvider()
        #startDate = date.today() - timedelta(days=365)
        #endDate = date.today()

        for date_str, stocks in portfolio_dict.items():
            date_obj = datetime.strptime(date_str, '%Y-%m-%d').date()  # Convert date string to date object
            for stock_name in stocks.keys():
                if stock_name not in stock_data:
                    stock_data[stock_name] = value_provider.get_asset_values(stock_name, "Close", startDate, endDate)

        portfolio_value_by_dates = {}

        for date_str, stocks in portfolio_dict.items():
            # Convert date string to datetime object with time set to midnight
            date_obj = datetime.strptime(date_str, '%Y-%m-%d')
            date_key = date_obj.strftime('%Y-%m-%d %H:%M:%S')  # Format to match stock_history keys
            total_value = 0

            for stock_name, quantity in stocks.items():
                stock_history = stock_data[stock_name]

                if date_key in stock_history:
                    stock_value = stock_history[date_key] * quantity
                    total_value += stock_value

            if total_value > 0:
                portfolio_value_by_dates[date_str] = total_value
        return portfolio_value_by_dates



    """
    def portfolio_value_for_dates(portfolio_dict, currency):
        stock_data = {}

        for date, stocks in portfolio_dict.items():
            for stock_name in stocks.keys():
                if stock_name not in stock_data:
                    stock_data[stock_name] = PortfolioValueProvider().get_asset_values(stock_name,"Close", startDate, endDate)

        portfolio_value_by_dates = {}

        for date, stocks in portfolio_dict.items():
            total_value = 0

            for stock_name, quantity in stocks.items():
                stock_history = stock_data[stock_name]

                if date in stock_history:
                    stock_value = stock_history[date] * quantity
                    total_value += stock_value

            if total_value > 0:
                portfolio_value_by_dates[date] = total_value
        return portfolio_value_by_dates
    """



# Data Collection
class PortfolioValueProvider:
    def __init__(self):
        self.conn = sqlite3.connect('stock_data.db')
        self.cursor = self.conn.cursor()


    def get_asset_value(self, symbol, metric, startDate, endDate):
        query = """
        SELECT d.value
        FROM Data d
        JOIN Companies c ON d.Company_ID = c.Company_ID
        JOIN Metrics m ON d.Metric_ID = m.Metric_ID
        WHERE c.company = ?
        AND m.metric = ?
        AND d.Date BETWEEN ? AND ?
        ORDER BY date DESC LIMIT 1
        """
        self.cursor.execute(query, (symbol, metric, startDate, endDate))
        result = self.cursor.fetchone()
        return result[0] if result else None

    def get_asset_values(self, symbol, metric, startDate, endDate):
        query = """
        SELECT d.Date, d.value
        FROM Data d
        JOIN Companies c ON d.Company_ID = c.Company_ID
        JOIN Metrics m ON d.Metric_ID = m.Metric_ID
        WHERE c.company = ?
        AND m.metric = ?
        AND d.Date BETWEEN ? AND ?
        ORDER BY d.date
        """
        self.cursor.execute(query, (symbol, metric, startDate, endDate))
        result = self.cursor.fetchall()
        return {row[0]: row[1] for row in result}  # Return a dictionary with dates as keys
        #return result
    #{row[0]: row[1] for row in result}

    @staticmethod
    def get_exchange_rate(country, target_currency='USD'):
        if country in PortfolioValueProvider.exchange_rates and target_currency in PortfolioValueProvider.exchange_rates[
            country]:
            return PortfolioValueProvider.exchange_rates[country][target_currency]
        else:
            return 1.0

    # Sample exchange rates (USD to other currencies)
    exchange_rates = {
        'USA': {
            'USD': 1.0,  # 1 USD to USD
            'INR': 75.0,  # Sample exchange rate: 1 USD to 75 INR
            'EUR': 0.85,  # Sample exchange rate: 1 USD to 0.85 EUR
        },
        'India': {
            'INR': 1.0,  # 1 INR to INR
            'USD': 0.013,  # Sample exchange rate: 1 INR to 0.013 USD
            'EUR': 0.011,  # Sample exchange rate: 1 INR to 0.011 EUR
        }
    }


# Output
class PortfolioOutput:
    def __init__(self, portfolio, currency):
        self.portfolio = portfolio
        self.currency = currency

    def portfolio_daily_value(self):
        return self.portfolio.calculate_current_value(self.currency)

    def portfolio_net_cost(self):
        return self.portfolio.calculate_net()[0]

    def portfolio_total_quantity(self):
        return self.portfolio.calculate_net()[1]

    def portfolio_net_cost_per_unit(self):
        return self.portfolio.calculate_net()[2]

    def portfolio_net(self):
        return self.portfolio.calculate_net()

    def portfolio_daily_values_oneyear(self):
        return self.portfolio.assets_on_dates_oneyear()

    def portfolio_value_date_rs(self):
        input_dict = self.portfolio_daily_values_oneyear()
        values = self.portfolio.portfolio_value_for_dates(input_dict, "USD")
        return values


# Final Output
class OutputForPHP:
    def __init__(self, currency):
        self.output_list = []
        self.portfolio = Portfolio()
        self.currency = currency

    def output_portfolio(self, trade_data):
        self.portfolio.add_trades(trade_data)
        portfolioOutput = PortfolioOutput(self.portfolio, self.currency)
        output = portfolioOutput.portfolio_net()
        output_currentValue = portfolioOutput.portfolio_daily_value()
        output_dailyvalues2 = portfolioOutput.portfolio_value_date_rs()
        output_dailyvalues = portfolioOutput.portfolio_daily_values_oneyear()

        output_list = [
            [
                key,
                [list(output[1].values())[i], list(output[0].values())[i], list(output[2].values())[i],
                 list(output[3].values())[i]]
            ]
            for i, key in enumerate(output[0].keys())
        ]
        return list(output_dailyvalues2.keys()), list(output_dailyvalues2.values()), output_list, list(output[0].values()), list(output[0].keys()), list(output[3].values())

# %%
def main(dataInput):
    #dataInput = json.loads(data_input)
    output = OutputForPHP("INR").output_portfolio(dataInput)
    # portfolio
    data_portfolio = output[2]

    # portfolio price chart data
    date_array = output[0]
    price_array = output[1]
    # final output array
    data_price = date_array, price_array, dataInput, data_portfolio, output[3], output[4], output[5]
    # Date Array, Price Array, Input data, Portfolio Array

    return data_price

# %%
main(data)
# Out:
# (['2024-03-26',
#   '2024-03-27',
#   '2024-03-28',
#   '2024-04-01',
#   '2024-04-02',
#   '2024-04-03',
#   '2024-04-04',
#   '2024-04-05',
#   '2024-04-08',
#   '2024-04-09',
#   '2024-04-10',
#   '2024-04-12',
#   '2024-04-15',
#   '2024-04-16',
#   '2024-04-18',
#   '2024-04-19',
#   '2024-04-22',
#   '2024-04-23',
#   '2024-04-24',
#   '2024-04-25',
#   '2024-04-26',
#   '2024-04-29',
#   '2024-04-30',
#   '2024-05-02',
#   '2024-05-03',
#   '2024-05-06',
#   '2024-05-07',
#   '2024-05-08',
#   '2024-05-09',
#   '2024-05-10',
#   '2024-05-13',
#   '2024-05-14',
#   '2024-05-15',
#   '2024-05-16',
#   '2024-05-17',
#   '2024-05-21',
#   '2024-05-22',
#   '2024-05-23',
#   '2024-05-24',
#   '2024-05-27',
#   '2024-05-28',
#   '2024-05-29',
#   '2024-05-30',
#   '2024-05-31',
#   '2024-06-03',
#   '2024-06-04',
#   '2024-06-05',
#   '2024-06-06',
#   '2024-06-07',
#   '2024-06-10',
#   '2024-06-11',
#   '2024-06-12',
#   '2024-06-13',
#   '2024-06-14',
#   '2024-06-18',
#   '2024-06-19',
#   '2024-06-20',
#   '2024-06-21',
#   '2024-06-24',
#   '2024-06-25',
#   '2024-06-26',
#   '2024-06-27',
#   '2024-06-28',
#   '2024-07-01',
#   '2024-07-02',
#   '2024-07-03',
#   '2024-07-04',
#   '2024-07-05',
#   '2024-07-08',
#   '2024-07-09',
#   '2024-07-10',
#   '2024-07-11',
#   '2024-07-12',
#   '2024-07-15',
#   '2024-07-16',
#   '2024-07-18',
#   '2024-07-19',
#   '2024-07-22',
#   '2024-07-23',
#   '2024-07-24',
#   '2024-07-25',
#   '2024-07-26',
#   '2024-07-29',
#   '2024-07-30',
#   '2024-07-31',
#   '2024-08-01',
#   '2024-08-02',
#   '2024-08-05',
#   '2024-08-06',
#   '2024-08-07',
#   '2024-08-08',
#   '2024-08-09',
#   '2024-08-12',
#   '2024-08-13',
#   '2024-08-14',
#   '2024-08-16',
#   '2024-08-19',
#   '2024-08-20',
#   '2024-08-21',
#   '2024-08-22',
#   '2024-08-23',
#   '2024-08-26',
#   '2024-08-27',
#   '2024-08-28',
#   '2024-08-29',
#   '2024-08-30',
#   '2024-09-02',
#   '2024-09-03',
#   '2024-09-04',
#   '2024-09-05',
#   '2024-09-06',
#   '2024-09-09',
#   '2024-09-10',
#   '2024-09-11',
#   '2024-09-12',
#   '2024-09-13',
#   '2024-09-16',
#   '2024-09-17',
#   '2024-09-18',
#   '2024-09-19',
#   '2024-09-20',
#   '2024-09-23',
#   '2024-09-24',
#   '2024-09-25',
#   '2024-09-26',
#   '2024-09-27',
#   '2024-09-30',
#   '2024-10-01',
#   '2024-10-03',
#   '2024-10-04',
#   '2024-10-07',
#   '2024-10-08',
#   '2024-10-09',
#   '2024-10-10',
#   '2024-10-11',
#   '2024-10-14',
#   '2024-10-15',
#   '2024-10-16',
#   '2024-10-17',
#   '2024-10-18',
#   '2024-10-21',
#   '2024-10-22',
#   '2024-10-23',
#   '2024-10-24',
#   '2024-10-25',
#   '2024-10-28',
#   '2024-10-29',
#   '2024-10-30',
#   '2024-10-31',
#   '2024-11-01',
#   '2024-11-04',
#   '2024-11-05',
#   '2024-11-06',
#   '2024-11-07',
#   '2024-11-08',
#   '2024-11-11',
#   '2024-11-12',
#   '2024-11-13',
#   '2024-11-14',
#   '2024-11-18',
#   '2024-11-19',
#   '2024-11-21',
#   '2024-11-22',
#   '2024-11-25',
#   '2024-11-26',
#   '2024-11-27',
#   '2024-11-28',
#   '2024-11-29',
#   '2024-12-02',
#   '2024-12-03',
#   '2024-12-04',
#   '2024-12-05',
#   '2024-12-06',
#   '2024-12-09',
#   '2024-12-10',
#   '2024-12-11',
#   '2024-12-12',
#   '2024-12-13',
#   '2024-12-16',
#   '2024-12-17',
#   '2024-12-18',
#   '2024-12-19',
#   '2024-12-20',
#   '2024-12-23',
#   '2024-12-24',
#   '2024-12-26',
#   '2024-12-27',
#   '2024-12-30',
#   '2024-12-31',
#   '2025-01-01',
#   '2025-01-02',
#   '2025-01-03',
#   '2025-01-06',
#   '2025-01-07',
#   '2025-01-08',
#   '2025-01-09',
#   '2025-01-10',
#   '2025-01-13',
#   '2025-01-14',
#   '2025-01-15',
#   '2025-01-16',
#   '2025-01-17',
#   '2025-01-20',
#   '2025-01-21',
#   '2025-01-22',
#   '2025-01-23',
#   '2025-01-24'],
#  [865762.0654296875,
#   866142.9931640625,
#   873699.1442871094,
#   884139.599609375,
#   884398.7231445312,
#   885148.5827636719,
#   897089.0649414062,
#   899811.3439941406,
#   899273.2104492188,
#   896992.5903320312,
#   896380.7775878906,
#   889625.0671386719,
#   875046.0327148438,
#   877829.3408203125,
#   873302.5122070312,
#   880499.1003417969,
#   881478.7060546875,
#   884669.1003417969,
#   882495.4040527344,
#   878878.6181640625,
#   875483.8305664062,
#   882692.0422363281,
#   878502.6965332031,
#   882663.5668945312,
#   877435.6787109375,
#   888998.2263183594,
#   908579.3359375,
#   898362.8259277344,
#   887695.3979492188,
#   891424.1271972656,
#   898088.7536621094,
#   894526.2890625,
#   885007.1655273438,
#   895141.3208007812,
#   888266.435546875,
#   885022.2509765625,
#   894566.1499023438,
#   906946.0876464844,
#   906854.6154785156,
#   911112.1118164062,
#   912831.38671875,
#   902836.8188476562,
#   896302.6086425781,
#   891942.0617675781,
#   905989.4848632812,
#   910831.4880371094,
#   943478.2751464844,
#   942156.6577148438,
#   953711.3513183594,
#   947227.5427246094,
#   946623.6169433594,
#   943187.6477050781,
#   940475.64453125,
#   943387.9895019531,
#   945387.6452636719,
#   949239.0112304688,
#   954583.6791992188,
#   949400.2709960938,
#   954470.8630371094,
#   960855.3295898438,
#   962208.8952636719,
#   967869.2724609375,
#   966867.939453125,
#   981030.2124023438,
#   984957.1545410156,
#   993266.8298339844,
#   986060.3698730469,
#   978563.4240722656,
#   980963.1396484375,
#   984930.498046875,
#   980429.3469238281,
#   980909.8303222656,
#   998376.4624023438,
#   997172.4304199219,
#   1007789.4091796875,
#   1022575.4467773438,
#   1018129.6215820312,
#   1025211.2255859375,
#   1026771.5686035156,
#   1016994.8974609375,
#   1019286.6589355469,
#   1024390.7336425781,
#   1021592.353515625,
#   1019455.1611328125,
#   1022819.4311523438,
#   1029075.9936523438,
#   1022039.7106933594,
#   1009283.5668945312,
#   1012344.55078125,
#   1018006.1108398438,
#   1019175.0,
#   1027485.9448242188,
#   1027097.0178222656,
#   1014524.7900390625,
#   1018482.255859375,
#   1034603.2873535156,
#   1038966.5844726562,
#   1044788.5546875,
#   1050717.4853515625,
#   1049493.2543945312,
#   1049288.7890625,
#   1055390.5688476562,
#   1045980.0659179688,
#   1046403.6096191406,
#   1049946.7260742188,
#   1050558.7048339844,
#   1048141.0986328125,
#   1052588.8195800781,
#   1059703.5668945312,
#   1059199.2456054688,
#   1055829.9584960938,
#   1070719.4750976562,
#   1071846.9055175781,
#   1069339.6008300781,
#   1084296.3586425781,
#   1080898.8623046875,
#   1070840.341796875,
#   1071506.474609375,
#   1066783.5009765625,
#   1070983.0883789062,
#   1087502.0483398438,
#   1097903.9672851562,
#   1087784.1284179688,
#   1090394.1296386719,
#   1097994.4970703125,
#   1091589.8962402344,
#   1084095.0390625,
#   1078809.3627929688,
#   1061259.53125,
#   1050469.2443847656,
#   1038895.5493164062,
#   1043386.4868164062,
#   1032256.6687011719,
#   1034224.0661621094,
#   1031430.0537109375,
#   1038760.9069824219,
#   1035754.9645996094,
#   1037521.9360351562,
#   1026169.4055175781,
#   1026196.1462402344,
#   1029926.7407226562,
#   1019850.9594726562,
#   1023971.4575195312,
#   1001926.9152832031,
#   1003378.4680175781,
#   1011763.8989257812,
#   1010256.9909667969,
#   1008449.0124511719,
#   997933.5375976562,
#   1000524.9169921875,
#   992023.3508300781,
#   1000622.5329589844,
#   1009461.4794921875,
#   1004106.9140625,
#   1009981.4501953125,
#   1012819.1137695312,
#   998274.2456054688,
#   987882.4621582031,
#   977700.1000976562,
#   977729.6252441406,
#   984158.3081054688,
#   980808.5327148438,
#   1001609.0222167969,
#   1018222.4670410156,
#   1021627.6245117188,
#   1026565.9643554688,
#   1013609.4836425781,
#   1020333.8012695312,
#   1019443.4204101562,
#   1025937.7563476562,
#   1032420.3674316406,
#   1044272.236328125,
#   1039669.8718261719,
#   1029595.9252929688,
#   1027874.2150878906,
#   1026953.4704589844,
#   1018548.525390625,
#   1029136.8359375,
#   1021289.6923828125,
#   1009065.5688476562,
#   1004929.8022460938,
#   996861.1645507812,
#   981543.5986328125,
#   986566.8286132812,
#   986962.8112792969,
#   984179.8095703125,
#   986779.9243164062,
#   982985.7604980469,
#   975447.9211425781,
#   978926.416015625,
#   992303.8647460938,
#   984695.6616210938,
#   971201.3720703125,
#   969837.4011230469,
#   972710.9790039062,
#   969045.390625,
#   980907.5354003906,
#   978354.4018554688,
#   964878.1677246094,
#   966145.3332519531,
#   960876.4978027344,
#   955113.4887695312,
#   953984.4946289062,
#   948488.0102539062,
#   963119.0063476562,
#   958852.0080566406,
#   963118.5302734375],
#  [{'date': 'Sat, 01 Mar 2025 00:00:00 GMT',
#    'id': 2,
#    'purchase_price': 1600.0,
#    'quantity': 10,
#    'symbol': 'HDFCBANK.NS'},
#   {'date': 'Sat, 01 Feb 2025 00:00:00 GMT',
#    'id': 3,
#    'purchase_price': 2200.0,
#    'quantity': 20,
#    'symbol': 'HINDUNILVR.NS'},
#   {'date': 'Tue, 04 Mar 2025 00:00:00 GMT',
#    'id': 4,
#    'purchase_price': 3500.0,
#    'quantity': 30,
#    'symbol': 'TCS.NS'},
#   {'date': 'Fri, 04 Aug 2023 00:00:00 GMT',
#    'id': 5,
#    'purchase_price': 900.0,
#    'quantity': 10,
#    'symbol': 'BBTC.NS'},
#   {'date': 'Sat, 01 Feb 2025 00:00:00 GMT',
#    'id': 6,
#    'purchase_price': 1200.0,
#    'quantity': 20,
#    'symbol': 'BALKRISIND.NS'},
#   {'date': 'Tue, 10 Sep 2019 00:00:00 GMT',
#    'id': 12,
#    'purchase_price': 1400.0,
#    'quantity': 90,
#    'symbol': 'HDFCBANK.NS'},
#   {'date': 'Wed, 19 May 2021 00:00:00 GMT',
#    'id': 13,
#    'purchase_price': 1500.0,
#    'quantity': 30,
#    'symbol': 'HDFCBANK.NS'},
#   {'date': 'Wed, 08 Feb 2023 00:00:00 GMT',
#    'id': 14,
#    'purchase_price': 1450.0,
#    'quantity': 70,
#    'symbol': 'HDFCBANK.NS'},
#   {'date': 'Wed, 08 Feb 2023 00:00:00 GMT',
#    'id': 15,
#    'purchase_price': 2450.0,
#    'quantity': 70,
#    'symbol': 'HINDUNILVR.NS'},
#   {'date': 'Thu, 11 Mar 2021 00:00:00 GMT',
#    'id': 16,
#    'purchase_price': 2150.0,
#    'quantity': 90,
#    'symbol': 'HINDUNILVR.NS'},
#   {'date': 'Wed, 10 Jul 2019 00:00:00 GMT',
#    'id': 17,
#    'purchase_price': 3000.0,
#    'quantity': 60,
#    'symbol': 'TCS.NS'},
#   {'date': 'Tue, 11 Mar 2025 00:00:00 GMT',
#    'id': 18,
#    'purchase_price': 1400.0,
#    'quantity': 40,
#    'symbol': 'BALKRISIND.NS'},
#   {'date': 'Tue, 11 Mar 2025 00:00:00 GMT',
#    'id': 19,
#    'purchase_price': 1400.0,
#    'quantity': 40,
#    'symbol': 'BALKRISIND.NS'}],
#  [['HDFCBANK.NS', [200, 288500.0, 1442.5, 329960.009765625]],
#   ['HINDUNILVR.NS', [180, 409000.0, 2272.222222222222, 426258.017578125]],
#   ['TCS.NS', [90, 285000.0, 3166.6666666666665, 373711.5087890625]],
#   ['BBTC.NS', [10, 9000.0, 900.0, 21619.49951171875]],
#   ['BALKRISIND.NS', [100, 136000.0, 1360.0, 265219.9951171875]]],
#  [288500.0, 409000.0, 285000.0, 9000.0, 136000.0],
#  ['HDFCBANK.NS', 'HINDUNILVR.NS', 'TCS.NS', 'BBTC.NS', 'BALKRISIND.NS'],
#  [329960.009765625,
#   426258.017578125,
#   373711.5087890625,
#   21619.49951171875,
#   265219.9951171875])

# %%
Portfolio
# Out:
# __main__.Portfolio

# %%
data
# Out:
# [{'date': 'Sat, 01 Mar 2025 00:00:00 GMT',
#   'id': 2,
#   'purchase_price': 1600.0,
#   'quantity': 10,
#   'symbol': 'HDFCBANK.NS'},
#  {'date': 'Sat, 01 Feb 2025 00:00:00 GMT',
#   'id': 3,
#   'purchase_price': 2200.0,
#   'quantity': 20,
#   'symbol': 'HINDUNILVR.NS'},
#  {'date': 'Tue, 04 Mar 2025 00:00:00 GMT',
#   'id': 4,
#   'purchase_price': 3500.0,
#   'quantity': 30,
#   'symbol': 'TCS.NS'},
#  {'date': 'Fri, 04 Aug 2023 00:00:00 GMT',
#   'id': 5,
#   'purchase_price': 900.0,
#   'quantity': 10,
#   'symbol': 'BBTC.NS'},
#  {'date': 'Sat, 01 Feb 2025 00:00:00 GMT',
#   'id': 6,
#   'purchase_price': 1200.0,
#   'quantity': 20,
#   'symbol': 'BALKRISIND.NS'},
#  {'date': 'Tue, 10 Sep 2019 00:00:00 GMT',
#   'id': 12,
#   'purchase_price': 1400.0,
#   'quantity': 90,
#   'symbol': 'HDFCBANK.NS'},
#  {'date': 'Wed, 19 May 2021 00:00:00 GMT',
#   'id': 13,
#   'purchase_price': 1500.0,
#   'quantity': 30,
#   'symbol': 'HDFCBANK.NS'},
#  {'date': 'Wed, 08 Feb 2023 00:00:00 GMT',
#   'id': 14,
#   'purchase_price': 1450.0,
#   'quantity': 70,
#   'symbol': 'HDFCBANK.NS'},
#  {'date': 'Wed, 08 Feb 2023 00:00:00 GMT',
#   'id': 15,
#   'purchase_price': 2450.0,
#   'quantity': 70,
#   'symbol': 'HINDUNILVR.NS'},
#  {'date': 'Thu, 11 Mar 2021 00:00:00 GMT',
#   'id': 16,
#   'purchase_price': 2150.0,
#   'quantity': 90,
#   'symbol': 'HINDUNILVR.NS'},
#  {'date': 'Wed, 10 Jul 2019 00:00:00 GMT',
#   'id': 17,
#   'purchase_price': 3000.0,
#   'quantity': 60,
#   'symbol': 'TCS.NS'},
#  {'date': 'Tue, 11 Mar 2025 00:00:00 GMT',
#   'id': 18,
#   'purchase_price': 1400.0,
#   'quantity': 40,
#   'symbol': 'BALKRISIND.NS'},
#  {'date': 'Tue, 11 Mar 2025 00:00:00 GMT',
#   'id': 19,
#   'purchase_price': 1400.0,
#   'quantity': 40,
#   'symbol': 'BALKRISIND.NS'}]

# %%
data[0]
# Out:
# {'date': 'Sat, 01 Mar 2025 00:00:00 GMT',
#  'id': 2,
#  'purchase_price': 1600.0,
#  'quantity': 10,
#  'symbol': 'HDFCBANK.NS'}

# %%
P1 = Portfolio()

# %%
P1.add_trades(data)

# %%
P1

# %%
dir(P1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_trade',
#  'add_trades',
#  'assets_on_dates_oneyear',
#  'calculate_current_value',
#  'calculate_daily_values_oneyear',
#  'calculate_net',
#  'get_portfolio_status_by_date',
#  'get_portfolio_status_for_dates',
#  'net_values',
#  'portfolio_status',
#  'portfolio_value_for_dates',
#  'trades',
#  'update_portfolio_status',
#  'value_provider']

# %%
P1.calculate_net()
# Out:
# ({'HDFCBANK.NS': 288500.0,
#   'HINDUNILVR.NS': 409000.0,
#   'TCS.NS': 285000.0,
#   'BBTC.NS': 9000.0,
#   'BALKRISIND.NS': 136000.0},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  {'HDFCBANK.NS': 1442.5,
#   'HINDUNILVR.NS': 2272.222222222222,
#   'TCS.NS': 3166.6666666666665,
#   'BBTC.NS': 900.0,
#   'BALKRISIND.NS': 1360.0},
#  {'HDFCBANK.NS': 329960.009765625,
#   'HINDUNILVR.NS': 426258.017578125,
#   'TCS.NS': 373711.5087890625,
#   'BBTC.NS': 21619.49951171875,
#   'BALKRISIND.NS': 265219.9951171875})

# %%
P1.assets_on_dates_oneyear()
# Out:
# {'2024-03-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-02-01': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-02': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-03': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-04': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-05': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-06': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-07': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-08': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-09': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-10': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-11': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-12': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-13': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-14': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-15': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-16': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-17': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-18': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-19': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-20': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-21': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-22': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-23': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-24': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-25': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-26': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-27': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-28': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-03-01': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-02': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-03': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-04': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-05': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-06': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-07': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-08': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-09': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-10': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-11': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-12': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-13': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-14': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-15': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-16': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-17': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-18': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-19': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-20': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-21': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-22': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100}}

# %%
P1.calculate_daily_values_oneyear("INR")
# Out:
# ([{'date': '2024-03-22', 'assets_quantity': {}},
#   {'date': '2024-03-23', 'assets_quantity': {}},
#   {'date': '2024-03-24', 'assets_quantity': {}},
#   {'date': '2024-03-25', 'assets_quantity': {}},
#   {'date': '2024-03-26', 'assets_quantity': {}},
#   {'date': '2024-03-27', 'assets_quantity': {}},
#   {'date': '2024-03-28', 'assets_quantity': {}},
#   {'date': '2024-03-29', 'assets_quantity': {}},
#   {'date': '2024-03-30', 'assets_quantity': {}},
#   {'date': '2024-03-31', 'assets_quantity': {}},
#   {'date': '2024-04-01', 'assets_quantity': {}},
#   {'date': '2024-04-02', 'assets_quantity': {}},
#   {'date': '2024-04-03', 'assets_quantity': {}},
#   {'date': '2024-04-04', 'assets_quantity': {}},
#   {'date': '2024-04-05', 'assets_quantity': {}},
#   {'date': '2024-04-06', 'assets_quantity': {}},
#   {'date': '2024-04-07', 'assets_quantity': {}},
#   {'date': '2024-04-08', 'assets_quantity': {}},
#   {'date': '2024-04-09', 'assets_quantity': {}},
#   {'date': '2024-04-10', 'assets_quantity': {}},
#   {'date': '2024-04-11', 'assets_quantity': {}},
#   {'date': '2024-04-12', 'assets_quantity': {}},
#   {'date': '2024-04-13', 'assets_quantity': {}},
#   {'date': '2024-04-14', 'assets_quantity': {}},
#   {'date': '2024-04-15', 'assets_quantity': {}},
#   {'date': '2024-04-16', 'assets_quantity': {}},
#   {'date': '2024-04-17', 'assets_quantity': {}},
#   {'date': '2024-04-18', 'assets_quantity': {}},
#   {'date': '2024-04-19', 'assets_quantity': {}},
#   {'date': '2024-04-20', 'assets_quantity': {}},
#   {'date': '2024-04-21', 'assets_quantity': {}},
#   {'date': '2024-04-22', 'assets_quantity': {}},
#   {'date': '2024-04-23', 'assets_quantity': {}},
#   {'date': '2024-04-24', 'assets_quantity': {}},
#   {'date': '2024-04-25', 'assets_quantity': {}},
#   {'date': '2024-04-26', 'assets_quantity': {}},
#   {'date': '2024-04-27', 'assets_quantity': {}},
#   {'date': '2024-04-28', 'assets_quantity': {}},
#   {'date': '2024-04-29', 'assets_quantity': {}},
#   {'date': '2024-04-30', 'assets_quantity': {}},
#   {'date': '2024-05-01', 'assets_quantity': {}},
#   {'date': '2024-05-02', 'assets_quantity': {}},
#   {'date': '2024-05-03', 'assets_quantity': {}},
#   {'date': '2024-05-04', 'assets_quantity': {}},
#   {'date': '2024-05-05', 'assets_quantity': {}},
#   {'date': '2024-05-06', 'assets_quantity': {}},
#   {'date': '2024-05-07', 'assets_quantity': {}},
#   {'date': '2024-05-08', 'assets_quantity': {}},
#   {'date': '2024-05-09', 'assets_quantity': {}},
#   {'date': '2024-05-10', 'assets_quantity': {}},
#   {'date': '2024-05-11', 'assets_quantity': {}},
#   {'date': '2024-05-12', 'assets_quantity': {}},
#   {'date': '2024-05-13', 'assets_quantity': {}},
#   {'date': '2024-05-14', 'assets_quantity': {}},
#   {'date': '2024-05-15', 'assets_quantity': {}},
#   {'date': '2024-05-16', 'assets_quantity': {}},
#   {'date': '2024-05-17', 'assets_quantity': {}},
#   {'date': '2024-05-18', 'assets_quantity': {}},
#   {'date': '2024-05-19', 'assets_quantity': {}},
#   {'date': '2024-05-20', 'assets_quantity': {}},
#   {'date': '2024-05-21', 'assets_quantity': {}},
#   {'date': '2024-05-22', 'assets_quantity': {}},
#   {'date': '2024-05-23', 'assets_quantity': {}},
#   {'date': '2024-05-24', 'assets_quantity': {}},
#   {'date': '2024-05-25', 'assets_quantity': {}},
#   {'date': '2024-05-26', 'assets_quantity': {}},
#   {'date': '2024-05-27', 'assets_quantity': {}},
#   {'date': '2024-05-28', 'assets_quantity': {}},
#   {'date': '2024-05-29', 'assets_quantity': {}},
#   {'date': '2024-05-30', 'assets_quantity': {}},
#   {'date': '2024-05-31', 'assets_quantity': {}},
#   {'date': '2024-06-01', 'assets_quantity': {}},
#   {'date': '2024-06-02', 'assets_quantity': {}},
#   {'date': '2024-06-03', 'assets_quantity': {}},
#   {'date': '2024-06-04', 'assets_quantity': {}},
#   {'date': '2024-06-05', 'assets_quantity': {}},
#   {'date': '2024-06-06', 'assets_quantity': {}},
#   {'date': '2024-06-07', 'assets_quantity': {}},
#   {'date': '2024-06-08', 'assets_quantity': {}},
#   {'date': '2024-06-09', 'assets_quantity': {}},
#   {'date': '2024-06-10', 'assets_quantity': {}},
#   {'date': '2024-06-11', 'assets_quantity': {}},
#   {'date': '2024-06-12', 'assets_quantity': {}},
#   {'date': '2024-06-13', 'assets_quantity': {}},
#   {'date': '2024-06-14', 'assets_quantity': {}},
#   {'date': '2024-06-15', 'assets_quantity': {}},
#   {'date': '2024-06-16', 'assets_quantity': {}},
#   {'date': '2024-06-17', 'assets_quantity': {}},
#   {'date': '2024-06-18', 'assets_quantity': {}},
#   {'date': '2024-06-19', 'assets_quantity': {}},
#   {'date': '2024-06-20', 'assets_quantity': {}},
#   {'date': '2024-06-21', 'assets_quantity': {}},
#   {'date': '2024-06-22', 'assets_quantity': {}},
#   {'date': '2024-06-23', 'assets_quantity': {}},
#   {'date': '2024-06-24', 'assets_quantity': {}},
#   {'date': '2024-06-25', 'assets_quantity': {}},
#   {'date': '2024-06-26', 'assets_quantity': {}},
#   {'date': '2024-06-27', 'assets_quantity': {}},
#   {'date': '2024-06-28', 'assets_quantity': {}},
#   {'date': '2024-06-29', 'assets_quantity': {}},
#   {'date': '2024-06-30', 'assets_quantity': {}},
#   {'date': '2024-07-01', 'assets_quantity': {}},
#   {'date': '2024-07-02', 'assets_quantity': {}},
#   {'date': '2024-07-03', 'assets_quantity': {}},
#   {'date': '2024-07-04', 'assets_quantity': {}},
#   {'date': '2024-07-05', 'assets_quantity': {}},
#   {'date': '2024-07-06', 'assets_quantity': {}},
#   {'date': '2024-07-07', 'assets_quantity': {}},
#   {'date': '2024-07-08', 'assets_quantity': {}},
#   {'date': '2024-07-09', 'assets_quantity': {}},
#   {'date': '2024-07-10', 'assets_quantity': {}},
#   {'date': '2024-07-11', 'assets_quantity': {}},
#   {'date': '2024-07-12', 'assets_quantity': {}},
#   {'date': '2024-07-13', 'assets_quantity': {}},
#   {'date': '2024-07-14', 'assets_quantity': {}},
#   {'date': '2024-07-15', 'assets_quantity': {}},
#   {'date': '2024-07-16', 'assets_quantity': {}},
#   {'date': '2024-07-17', 'assets_quantity': {}},
#   {'date': '2024-07-18', 'assets_quantity': {}},
#   {'date': '2024-07-19', 'assets_quantity': {}},
#   {'date': '2024-07-20', 'assets_quantity': {}},
#   {'date': '2024-07-21', 'assets_quantity': {}},
#   {'date': '2024-07-22', 'assets_quantity': {}},
#   {'date': '2024-07-23', 'assets_quantity': {}},
#   {'date': '2024-07-24', 'assets_quantity': {}},
#   {'date': '2024-07-25', 'assets_quantity': {}},
#   {'date': '2024-07-26', 'assets_quantity': {}},
#   {'date': '2024-07-27', 'assets_quantity': {}},
#   {'date': '2024-07-28', 'assets_quantity': {}},
#   {'date': '2024-07-29', 'assets_quantity': {}},
#   {'date': '2024-07-30', 'assets_quantity': {}},
#   {'date': '2024-07-31', 'assets_quantity': {}},
#   {'date': '2024-08-01', 'assets_quantity': {}},
#   {'date': '2024-08-02', 'assets_quantity': {}},
#   {'date': '2024-08-03', 'assets_quantity': {}},
#   {'date': '2024-08-04', 'assets_quantity': {}},
#   {'date': '2024-08-05', 'assets_quantity': {}},
#   {'date': '2024-08-06', 'assets_quantity': {}},
#   {'date': '2024-08-07', 'assets_quantity': {}},
#   {'date': '2024-08-08', 'assets_quantity': {}},
#   {'date': '2024-08-09', 'assets_quantity': {}},
#   {'date': '2024-08-10', 'assets_quantity': {}},
#   {'date': '2024-08-11', 'assets_quantity': {}},
#   {'date': '2024-08-12', 'assets_quantity': {}},
#   {'date': '2024-08-13', 'assets_quantity': {}},
#   {'date': '2024-08-14', 'assets_quantity': {}},
#   {'date': '2024-08-15', 'assets_quantity': {}},
#   {'date': '2024-08-16', 'assets_quantity': {}},
#   {'date': '2024-08-17', 'assets_quantity': {}},
#   {'date': '2024-08-18', 'assets_quantity': {}},
#   {'date': '2024-08-19', 'assets_quantity': {}},
#   {'date': '2024-08-20', 'assets_quantity': {}},
#   {'date': '2024-08-21', 'assets_quantity': {}},
#   {'date': '2024-08-22', 'assets_quantity': {}},
#   {'date': '2024-08-23', 'assets_quantity': {}},
#   {'date': '2024-08-24', 'assets_quantity': {}},
#   {'date': '2024-08-25', 'assets_quantity': {}},
#   {'date': '2024-08-26', 'assets_quantity': {}},
#   {'date': '2024-08-27', 'assets_quantity': {}},
#   {'date': '2024-08-28', 'assets_quantity': {}},
#   {'date': '2024-08-29', 'assets_quantity': {}},
#   {'date': '2024-08-30', 'assets_quantity': {}},
#   {'date': '2024-08-31', 'assets_quantity': {}},
#   {'date': '2024-09-01', 'assets_quantity': {}},
#   {'date': '2024-09-02', 'assets_quantity': {}},
#   {'date': '2024-09-03', 'assets_quantity': {}},
#   {'date': '2024-09-04', 'assets_quantity': {}},
#   {'date': '2024-09-05', 'assets_quantity': {}},
#   {'date': '2024-09-06', 'assets_quantity': {}},
#   {'date': '2024-09-07', 'assets_quantity': {}},
#   {'date': '2024-09-08', 'assets_quantity': {}},
#   {'date': '2024-09-09', 'assets_quantity': {}},
#   {'date': '2024-09-10', 'assets_quantity': {}},
#   {'date': '2024-09-11', 'assets_quantity': {}},
#   {'date': '2024-09-12', 'assets_quantity': {}},
#   {'date': '2024-09-13', 'assets_quantity': {}},
#   {'date': '2024-09-14', 'assets_quantity': {}},
#   {'date': '2024-09-15', 'assets_quantity': {}},
#   {'date': '2024-09-16', 'assets_quantity': {}},
#   {'date': '2024-09-17', 'assets_quantity': {}},
#   {'date': '2024-09-18', 'assets_quantity': {}},
#   {'date': '2024-09-19', 'assets_quantity': {}},
#   {'date': '2024-09-20', 'assets_quantity': {}},
#   {'date': '2024-09-21', 'assets_quantity': {}},
#   {'date': '2024-09-22', 'assets_quantity': {}},
#   {'date': '2024-09-23', 'assets_quantity': {}},
#   {'date': '2024-09-24', 'assets_quantity': {}},
#   {'date': '2024-09-25', 'assets_quantity': {}},
#   {'date': '2024-09-26', 'assets_quantity': {}},
#   {'date': '2024-09-27', 'assets_quantity': {}},
#   {'date': '2024-09-28', 'assets_quantity': {}},
#   {'date': '2024-09-29', 'assets_quantity': {}},
#   {'date': '2024-09-30', 'assets_quantity': {}},
#   {'date': '2024-10-01', 'assets_quantity': {}},
#   {'date': '2024-10-02', 'assets_quantity': {}},
#   {'date': '2024-10-03', 'assets_quantity': {}},
#   {'date': '2024-10-04', 'assets_quantity': {}},
#   {'date': '2024-10-05', 'assets_quantity': {}},
#   {'date': '2024-10-06', 'assets_quantity': {}},
#   {'date': '2024-10-07', 'assets_quantity': {}},
#   {'date': '2024-10-08', 'assets_quantity': {}},
#   {'date': '2024-10-09', 'assets_quantity': {}},
#   {'date': '2024-10-10', 'assets_quantity': {}},
#   {'date': '2024-10-11', 'assets_quantity': {}},
#   {'date': '2024-10-12', 'assets_quantity': {}},
#   {'date': '2024-10-13', 'assets_quantity': {}},
#   {'date': '2024-10-14', 'assets_quantity': {}},
#   {'date': '2024-10-15', 'assets_quantity': {}},
#   {'date': '2024-10-16', 'assets_quantity': {}},
#   {'date': '2024-10-17', 'assets_quantity': {}},
#   {'date': '2024-10-18', 'assets_quantity': {}},
#   {'date': '2024-10-19', 'assets_quantity': {}},
#   {'date': '2024-10-20', 'assets_quantity': {}},
#   {'date': '2024-10-21', 'assets_quantity': {}},
#   {'date': '2024-10-22', 'assets_quantity': {}},
#   {'date': '2024-10-23', 'assets_quantity': {}},
#   {'date': '2024-10-24', 'assets_quantity': {}},
#   {'date': '2024-10-25', 'assets_quantity': {}},
#   {'date': '2024-10-26', 'assets_quantity': {}},
#   {'date': '2024-10-27', 'assets_quantity': {}},
#   {'date': '2024-10-28', 'assets_quantity': {}},
#   {'date': '2024-10-29', 'assets_quantity': {}},
#   {'date': '2024-10-30', 'assets_quantity': {}},
#   {'date': '2024-10-31', 'assets_quantity': {}},
#   {'date': '2024-11-01', 'assets_quantity': {}},
#   {'date': '2024-11-02', 'assets_quantity': {}},
#   {'date': '2024-11-03', 'assets_quantity': {}},
#   {'date': '2024-11-04', 'assets_quantity': {}},
#   {'date': '2024-11-05', 'assets_quantity': {}},
#   {'date': '2024-11-06', 'assets_quantity': {}},
#   {'date': '2024-11-07', 'assets_quantity': {}},
#   {'date': '2024-11-08', 'assets_quantity': {}},
#   {'date': '2024-11-09', 'assets_quantity': {}},
#   {'date': '2024-11-10', 'assets_quantity': {}},
#   {'date': '2024-11-11', 'assets_quantity': {}},
#   {'date': '2024-11-12', 'assets_quantity': {}},
#   {'date': '2024-11-13', 'assets_quantity': {}},
#   {'date': '2024-11-14', 'assets_quantity': {}},
#   {'date': '2024-11-15', 'assets_quantity': {}},
#   {'date': '2024-11-16', 'assets_quantity': {}},
#   {'date': '2024-11-17', 'assets_quantity': {}},
#   {'date': '2024-11-18', 'assets_quantity': {}},
#   {'date': '2024-11-19', 'assets_quantity': {}},
#   {'date': '2024-11-20', 'assets_quantity': {}},
#   {'date': '2024-11-21', 'assets_quantity': {}},
#   {'date': '2024-11-22', 'assets_quantity': {}},
#   {'date': '2024-11-23', 'assets_quantity': {}},
#   {'date': '2024-11-24', 'assets_quantity': {}},
#   {'date': '2024-11-25', 'assets_quantity': {}},
#   {'date': '2024-11-26', 'assets_quantity': {}},
#   {'date': '2024-11-27', 'assets_quantity': {}},
#   {'date': '2024-11-28', 'assets_quantity': {}},
#   {'date': '2024-11-29', 'assets_quantity': {}},
#   {'date': '2024-11-30', 'assets_quantity': {}},
#   {'date': '2024-12-01', 'assets_quantity': {}},
#   {'date': '2024-12-02', 'assets_quantity': {}},
#   {'date': '2024-12-03', 'assets_quantity': {}},
#   {'date': '2024-12-04', 'assets_quantity': {}},
#   {'date': '2024-12-05', 'assets_quantity': {}},
#   {'date': '2024-12-06', 'assets_quantity': {}},
#   {'date': '2024-12-07', 'assets_quantity': {}},
#   {'date': '2024-12-08', 'assets_quantity': {}},
#   {'date': '2024-12-09', 'assets_quantity': {}},
#   {'date': '2024-12-10', 'assets_quantity': {}},
#   {'date': '2024-12-11', 'assets_quantity': {}},
#   {'date': '2024-12-12', 'assets_quantity': {}},
#   {'date': '2024-12-13', 'assets_quantity': {}},
#   {'date': '2024-12-14', 'assets_quantity': {}},
#   {'date': '2024-12-15', 'assets_quantity': {}},
#   {'date': '2024-12-16', 'assets_quantity': {}},
#   {'date': '2024-12-17', 'assets_quantity': {}},
#   {'date': '2024-12-18', 'assets_quantity': {}},
#   {'date': '2024-12-19', 'assets_quantity': {}},
#   {'date': '2024-12-20', 'assets_quantity': {}},
#   {'date': '2024-12-21', 'assets_quantity': {}},
#   {'date': '2024-12-22', 'assets_quantity': {}},
#   {'date': '2024-12-23', 'assets_quantity': {}},
#   {'date': '2024-12-24', 'assets_quantity': {}},
#   {'date': '2024-12-25', 'assets_quantity': {}},
#   {'date': '2024-12-26', 'assets_quantity': {}},
#   {'date': '2024-12-27', 'assets_quantity': {}},
#   {'date': '2024-12-28', 'assets_quantity': {}},
#   {'date': '2024-12-29', 'assets_quantity': {}},
#   {'date': '2024-12-30', 'assets_quantity': {}},
#   {'date': '2024-12-31', 'assets_quantity': {}},
#   {'date': '2025-01-01', 'assets_quantity': {}},
#   {'date': '2025-01-02', 'assets_quantity': {}},
#   {'date': '2025-01-03', 'assets_quantity': {}},
#   {'date': '2025-01-04', 'assets_quantity': {}},
#   {'date': '2025-01-05', 'assets_quantity': {}},
#   {'date': '2025-01-06', 'assets_quantity': {}},
#   {'date': '2025-01-07', 'assets_quantity': {}},
#   {'date': '2025-01-08', 'assets_quantity': {}},
#   {'date': '2025-01-09', 'assets_quantity': {}},
#   {'date': '2025-01-10', 'assets_quantity': {}},
#   {'date': '2025-01-11', 'assets_quantity': {}},
#   {'date': '2025-01-12', 'assets_quantity': {}},
#   {'date': '2025-01-13', 'assets_quantity': {}},
#   {'date': '2025-01-14', 'assets_quantity': {}},
#   {'date': '2025-01-15', 'assets_quantity': {}},
#   {'date': '2025-01-16', 'assets_quantity': {}},
#   {'date': '2025-01-17', 'assets_quantity': {}},
#   {'date': '2025-01-18', 'assets_quantity': {}},
#   {'date': '2025-01-19', 'assets_quantity': {}},
#   {'date': '2025-01-20', 'assets_quantity': {}},
#   {'date': '2025-01-21', 'assets_quantity': {}},
#   {'date': '2025-01-22', 'assets_quantity': {}},
#   {'date': '2025-01-23', 'assets_quantity': {}},
#   {'date': '2025-01-24', 'assets_quantity': {}},
#   {'date': '2025-01-25', 'assets_quantity': {}},
#   {'date': '2025-01-26', 'assets_quantity': {}},
#   {'date': '2025-01-27', 'assets_quantity': {}},
#   {'date': '2025-01-28', 'assets_quantity': {}},
#   {'date': '2025-01-29', 'assets_quantity': {}},
#   {'date': '2025-01-30', 'assets_quantity': {}},
#   {'date': '2025-01-31', 'assets_quantity': {}},
#   {'date': '2025-02-01', 'assets_quantity': {}},
#   {'date': '2025-02-02', 'assets_quantity': {}},
#   {'date': '2025-02-03', 'assets_quantity': {}},
#   {'date': '2025-02-04', 'assets_quantity': {}},
#   {'date': '2025-02-05', 'assets_quantity': {}},
#   {'date': '2025-02-06', 'assets_quantity': {}},
#   {'date': '2025-02-07', 'assets_quantity': {}},
#   {'date': '2025-02-08', 'assets_quantity': {}},
#   {'date': '2025-02-09', 'assets_quantity': {}},
#   {'date': '2025-02-10', 'assets_quantity': {}},
#   {'date': '2025-02-11', 'assets_quantity': {}},
#   {'date': '2025-02-12', 'assets_quantity': {}},
#   {'date': '2025-02-13', 'assets_quantity': {}},
#   {'date': '2025-02-14', 'assets_quantity': {}},
#   {'date': '2025-02-15', 'assets_quantity': {}},
#   {'date': '2025-02-16', 'assets_quantity': {}},
#   {'date': '2025-02-17', 'assets_quantity': {}},
#   {'date': '2025-02-18', 'assets_quantity': {}},
#   {'date': '2025-02-19', 'assets_quantity': {}},
#   {'date': '2025-02-20', 'assets_quantity': {}},
#   {'date': '2025-02-21', 'assets_quantity': {}},
#   {'date': '2025-02-22', 'assets_quantity': {}},
#   {'date': '2025-02-23', 'assets_quantity': {}},
#   {'date': '2025-02-24', 'assets_quantity': {}},
#   {'date': '2025-02-25', 'assets_quantity': {}},
#   {'date': '2025-02-26', 'assets_quantity': {}},
#   {'date': '2025-02-27', 'assets_quantity': {}},
#   {'date': '2025-02-28', 'assets_quantity': {}},
#   {'date': '2025-03-01', 'assets_quantity': {}},
#   {'date': '2025-03-02', 'assets_quantity': {}},
#   {'date': '2025-03-03', 'assets_quantity': {}},
#   {'date': '2025-03-04', 'assets_quantity': {}},
#   {'date': '2025-03-05', 'assets_quantity': {}},
#   {'date': '2025-03-06', 'assets_quantity': {}},
#   {'date': '2025-03-07', 'assets_quantity': {}},
#   {'date': '2025-03-08', 'assets_quantity': {}},
#   {'date': '2025-03-09', 'assets_quantity': {}},
#   {'date': '2025-03-10', 'assets_quantity': {}},
#   {'date': '2025-03-11', 'assets_quantity': {}},
#   {'date': '2025-03-12', 'assets_quantity': {}},
#   {'date': '2025-03-13', 'assets_quantity': {}},
#   {'date': '2025-03-14', 'assets_quantity': {}},
#   {'date': '2025-03-15', 'assets_quantity': {}},
#   {'date': '2025-03-16', 'assets_quantity': {}},
#   {'date': '2025-03-17', 'assets_quantity': {}},
#   {'date': '2025-03-18', 'assets_quantity': {}},
#   {'date': '2025-03-19', 'assets_quantity': {}},
#   {'date': '2025-03-20', 'assets_quantity': {}},
#   {'date': '2025-03-21', 'assets_quantity': {}},
#   {'date': '2025-03-22', 'assets_quantity': {}}],
#  ['2024-03-22',
#   '2024-03-23',
#   '2024-03-24',
#   '2024-03-25',
#   '2024-03-26',
#   '2024-03-27',
#   '2024-03-28',
#   '2024-03-29',
#   '2024-03-30',
#   '2024-03-31',
#   '2024-04-01',
#   '2024-04-02',
#   '2024-04-03',
#   '2024-04-04',
#   '2024-04-05',
#   '2024-04-06',
#   '2024-04-07',
#   '2024-04-08',
#   '2024-04-09',
#   '2024-04-10',
#   '2024-04-11',
#   '2024-04-12',
#   '2024-04-13',
#   '2024-04-14',
#   '2024-04-15',
#   '2024-04-16',
#   '2024-04-17',
#   '2024-04-18',
#   '2024-04-19',
#   '2024-04-20',
#   '2024-04-21',
#   '2024-04-22',
#   '2024-04-23',
#   '2024-04-24',
#   '2024-04-25',
#   '2024-04-26',
#   '2024-04-27',
#   '2024-04-28',
#   '2024-04-29',
#   '2024-04-30',
#   '2024-05-01',
#   '2024-05-02',
#   '2024-05-03',
#   '2024-05-04',
#   '2024-05-05',
#   '2024-05-06',
#   '2024-05-07',
#   '2024-05-08',
#   '2024-05-09',
#   '2024-05-10',
#   '2024-05-11',
#   '2024-05-12',
#   '2024-05-13',
#   '2024-05-14',
#   '2024-05-15',
#   '2024-05-16',
#   '2024-05-17',
#   '2024-05-18',
#   '2024-05-19',
#   '2024-05-20',
#   '2024-05-21',
#   '2024-05-22',
#   '2024-05-23',
#   '2024-05-24',
#   '2024-05-25',
#   '2024-05-26',
#   '2024-05-27',
#   '2024-05-28',
#   '2024-05-29',
#   '2024-05-30',
#   '2024-05-31',
#   '2024-06-01',
#   '2024-06-02',
#   '2024-06-03',
#   '2024-06-04',
#   '2024-06-05',
#   '2024-06-06',
#   '2024-06-07',
#   '2024-06-08',
#   '2024-06-09',
#   '2024-06-10',
#   '2024-06-11',
#   '2024-06-12',
#   '2024-06-13',
#   '2024-06-14',
#   '2024-06-15',
#   '2024-06-16',
#   '2024-06-17',
#   '2024-06-18',
#   '2024-06-19',
#   '2024-06-20',
#   '2024-06-21',
#   '2024-06-22',
#   '2024-06-23',
#   '2024-06-24',
#   '2024-06-25',
#   '2024-06-26',
#   '2024-06-27',
#   '2024-06-28',
#   '2024-06-29',
#   '2024-06-30',
#   '2024-07-01',
#   '2024-07-02',
#   '2024-07-03',
#   '2024-07-04',
#   '2024-07-05',
#   '2024-07-06',
#   '2024-07-07',
#   '2024-07-08',
#   '2024-07-09',
#   '2024-07-10',
#   '2024-07-11',
#   '2024-07-12',
#   '2024-07-13',
#   '2024-07-14',
#   '2024-07-15',
#   '2024-07-16',
#   '2024-07-17',
#   '2024-07-18',
#   '2024-07-19',
#   '2024-07-20',
#   '2024-07-21',
#   '2024-07-22',
#   '2024-07-23',
#   '2024-07-24',
#   '2024-07-25',
#   '2024-07-26',
#   '2024-07-27',
#   '2024-07-28',
#   '2024-07-29',
#   '2024-07-30',
#   '2024-07-31',
#   '2024-08-01',
#   '2024-08-02',
#   '2024-08-03',
#   '2024-08-04',
#   '2024-08-05',
#   '2024-08-06',
#   '2024-08-07',
#   '2024-08-08',
#   '2024-08-09',
#   '2024-08-10',
#   '2024-08-11',
#   '2024-08-12',
#   '2024-08-13',
#   '2024-08-14',
#   '2024-08-15',
#   '2024-08-16',
#   '2024-08-17',
#   '2024-08-18',
#   '2024-08-19',
#   '2024-08-20',
#   '2024-08-21',
#   '2024-08-22',
#   '2024-08-23',
#   '2024-08-24',
#   '2024-08-25',
#   '2024-08-26',
#   '2024-08-27',
#   '2024-08-28',
#   '2024-08-29',
#   '2024-08-30',
#   '2024-08-31',
#   '2024-09-01',
#   '2024-09-02',
#   '2024-09-03',
#   '2024-09-04',
#   '2024-09-05',
#   '2024-09-06',
#   '2024-09-07',
#   '2024-09-08',
#   '2024-09-09',
#   '2024-09-10',
#   '2024-09-11',
#   '2024-09-12',
#   '2024-09-13',
#   '2024-09-14',
#   '2024-09-15',
#   '2024-09-16',
#   '2024-09-17',
#   '2024-09-18',
#   '2024-09-19',
#   '2024-09-20',
#   '2024-09-21',
#   '2024-09-22',
#   '2024-09-23',
#   '2024-09-24',
#   '2024-09-25',
#   '2024-09-26',
#   '2024-09-27',
#   '2024-09-28',
#   '2024-09-29',
#   '2024-09-30',
#   '2024-10-01',
#   '2024-10-02',
#   '2024-10-03',
#   '2024-10-04',
#   '2024-10-05',
#   '2024-10-06',
#   '2024-10-07',
#   '2024-10-08',
#   '2024-10-09',
#   '2024-10-10',
#   '2024-10-11',
#   '2024-10-12',
#   '2024-10-13',
#   '2024-10-14',
#   '2024-10-15',
#   '2024-10-16',
#   '2024-10-17',
#   '2024-10-18',
#   '2024-10-19',
#   '2024-10-20',
#   '2024-10-21',
#   '2024-10-22',
#   '2024-10-23',
#   '2024-10-24',
#   '2024-10-25',
#   '2024-10-26',
#   '2024-10-27',
#   '2024-10-28',
#   '2024-10-29',
#   '2024-10-30',
#   '2024-10-31',
#   '2024-11-01',
#   '2024-11-02',
#   '2024-11-03',
#   '2024-11-04',
#   '2024-11-05',
#   '2024-11-06',
#   '2024-11-07',
#   '2024-11-08',
#   '2024-11-09',
#   '2024-11-10',
#   '2024-11-11',
#   '2024-11-12',
#   '2024-11-13',
#   '2024-11-14',
#   '2024-11-15',
#   '2024-11-16',
#   '2024-11-17',
#   '2024-11-18',
#   '2024-11-19',
#   '2024-11-20',
#   '2024-11-21',
#   '2024-11-22',
#   '2024-11-23',
#   '2024-11-24',
#   '2024-11-25',
#   '2024-11-26',
#   '2024-11-27',
#   '2024-11-28',
#   '2024-11-29',
#   '2024-11-30',
#   '2024-12-01',
#   '2024-12-02',
#   '2024-12-03',
#   '2024-12-04',
#   '2024-12-05',
#   '2024-12-06',
#   '2024-12-07',
#   '2024-12-08',
#   '2024-12-09',
#   '2024-12-10',
#   '2024-12-11',
#   '2024-12-12',
#   '2024-12-13',
#   '2024-12-14',
#   '2024-12-15',
#   '2024-12-16',
#   '2024-12-17',
#   '2024-12-18',
#   '2024-12-19',
#   '2024-12-20',
#   '2024-12-21',
#   '2024-12-22',
#   '2024-12-23',
#   '2024-12-24',
#   '2024-12-25',
#   '2024-12-26',
#   '2024-12-27',
#   '2024-12-28',
#   '2024-12-29',
#   '2024-12-30',
#   '2024-12-31',
#   '2025-01-01',
#   '2025-01-02',
#   '2025-01-03',
#   '2025-01-04',
#   '2025-01-05',
#   '2025-01-06',
#   '2025-01-07',
#   '2025-01-08',
#   '2025-01-09',
#   '2025-01-10',
#   '2025-01-11',
#   '2025-01-12',
#   '2025-01-13',
#   '2025-01-14',
#   '2025-01-15',
#   '2025-01-16',
#   '2025-01-17',
#   '2025-01-18',
#   '2025-01-19',
#   '2025-01-20',
#   '2025-01-21',
#   '2025-01-22',
#   '2025-01-23',
#   '2025-01-24',
#   '2025-01-25',
#   '2025-01-26',
#   '2025-01-27',
#   '2025-01-28',
#   '2025-01-29',
#   '2025-01-30',
#   '2025-01-31',
#   '2025-02-01',
#   '2025-02-02',
#   '2025-02-03',
#   '2025-02-04',
#   '2025-02-05',
#   '2025-02-06',
#   '2025-02-07',
#   '2025-02-08',
#   '2025-02-09',
#   '2025-02-10',
#   '2025-02-11',
#   '2025-02-12',
#   '2025-02-13',
#   '2025-02-14',
#   '2025-02-15',
#   '2025-02-16',
#   '2025-02-17',
#   '2025-02-18',
#   '2025-02-19',
#   '2025-02-20',
#   '2025-02-21',
#   '2025-02-22',
#   '2025-02-23',
#   '2025-02-24',
#   '2025-02-25',
#   '2025-02-26',
#   '2025-02-27',
#   '2025-02-28',
#   '2025-03-01',
#   '2025-03-02',
#   '2025-03-03',
#   '2025-03-04',
#   '2025-03-05',
#   '2025-03-06',
#   '2025-03-07',
#   '2025-03-08',
#   '2025-03-09',
#   '2025-03-10',
#   '2025-03-11',
#   '2025-03-12',
#   '2025-03-13',
#   '2025-03-14',
#   '2025-03-15',
#   '2025-03-16',
#   '2025-03-17',
#   '2025-03-18',
#   '2025-03-19',
#   '2025-03-20',
#   '2025-03-21',
#   '2025-03-22'])

# %%
P1.portfolio_value_for_dates(P1.assets_on_dates_oneyear(), "INR")
# Out:
# {}

# %%
P1.assets_on_dates_oneyear()
# Out:
# {'2024-03-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-02-01': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-02': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-03': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-04': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-05': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-06': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-07': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-08': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-09': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-10': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-11': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-12': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-13': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-14': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-15': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-16': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-17': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-18': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-19': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-20': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-21': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-22': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-23': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-24': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-25': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-26': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-27': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-28': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-03-01': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-02': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-03': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-04': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-05': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-06': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-07': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-08': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-09': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-10': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-11': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-12': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-13': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-14': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-15': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-16': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-17': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-18': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-19': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-20': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-21': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-22': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100}}

# %%
P1.portfolio_net()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 P1.portfolio_net()
#
# AttributeError: 'Portfolio' object has no attribute 'portfolio_net'

# %%
P_output = PortfolioOutput(P1, "INR")

# %%
P_output

# %%
P_output.portfolio_net()
# Out:
# ({'HDFCBANK.NS': 288500.0,
#   'HINDUNILVR.NS': 409000.0,
#   'TCS.NS': 285000.0,
#   'BBTC.NS': 9000.0,
#   'BALKRISIND.NS': 136000.0},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  {'HDFCBANK.NS': 1442.5,
#   'HINDUNILVR.NS': 2272.222222222222,
#   'TCS.NS': 3166.6666666666665,
#   'BBTC.NS': 900.0,
#   'BALKRISIND.NS': 1360.0},
#  {'HDFCBANK.NS': 329960.009765625,
#   'HINDUNILVR.NS': 426258.017578125,
#   'TCS.NS': 373711.5087890625,
#   'BBTC.NS': 21619.49951171875,
#   'BALKRISIND.NS': 265219.9951171875})

# %%
P_output.portfolio_daily_value()
# Out:
# {'HDFCBANK.NS': 16498.00048828125,
#  'HINDUNILVR.NS': 47362.001953125,
#  'TCS.NS': 124570.5029296875,
#  'BALKRISIND.NS': 106087.998046875}

# %%
P_output.portfolio_daily_values_oneyear()
# Out:
# {'2024-03-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-02-01': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-02': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-03': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-04': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-05': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-06': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-07': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-08': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-09': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-10': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-11': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-12': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-13': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-14': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-15': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-16': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-17': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-18': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-19': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-20': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-21': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-22': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-23': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-24': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-25': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-26': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-27': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-28': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-03-01': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-02': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-03': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-04': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-05': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-06': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-07': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-08': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-09': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-10': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-11': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-12': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-13': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-14': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-15': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-16': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-17': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-18': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-19': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-20': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-21': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-22': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100}}

# %%
P_output.portfolio_value_date_rs()
# Out:
# {}

# %%
output_p = P_output.portfolio_net()

# %%
output_p[1].values()
# Out:
# dict_values([200, 180, 90, 10, 100])

# %%
output_p[0].values()
# Out:
# dict_values([288500.0, 409000.0, 285000.0, 9000.0, 136000.0])

# %%
output_p[2].values()
# Out:
# dict_values([1442.5, 2272.222222222222, 3166.6666666666665, 900.0, 1360.0])

# %%
output_p[3].values()
# Out:
# dict_values([329960.009765625, 426258.017578125, 373711.5087890625, 21619.49951171875, 265219.9951171875])

# %%
P_output.portfolio_value_date_rs()
# Out:
# {}

# %%
class OutputForPHP:
    def __init__(self, currency):
        self.output_list = []
        self.portfolio = Portfolio()
        self.currency = currency

    def output_portfolio(self, trade_data):
        self.portfolio.add_trades(trade_data)
        portfolioOutput = PortfolioOutput(self.portfolio, self.currency)
        output = portfolioOutput.portfolio_net()
        output_currentValue = portfolioOutput.portfolio_daily_value()
        output_dailyvalues2 = portfolioOutput.portfolio_value_date_rs()
        output_dailyvalues = portfolioOutput.portfolio_daily_values_oneyear()

        output_list = [
            [
                key,
                [list(output[1].values())[i], list(output[0].values())[i], list(output[2].values())[i],
                 list(output[3].values())[i]]
            ]
            for i, key in enumerate(output[0].keys())
        ]
        return list(output_dailyvalues2.keys()), list(output_dailyvalues2.values()), output_list, list(output[0].values()), list(output[0].keys()), list(output[3].values())

# %%
P1.calculate_current_value("INR")
# Out:
# {'HDFCBANK.NS': 16498.00048828125,
#  'HINDUNILVR.NS': 47362.001953125,
#  'TCS.NS': 124570.5029296875,
#  'BALKRISIND.NS': 106087.998046875}

# %%
P1.assets_on_dates_oneyear()
# Out:
# {'2024-03-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-02-01': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-02': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-03': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-04': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-05': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-06': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-07': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-08': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-09': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-10': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-11': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-12': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-13': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-14': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-15': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-16': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-17': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-18': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-19': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-20': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-21': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-22': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-23': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-24': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-25': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-26': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-27': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-28': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-03-01': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-02': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-03': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-04': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-05': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-06': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-07': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-08': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-09': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-10': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-11': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-12': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-13': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-14': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-15': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-16': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-17': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-18': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-19': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-20': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-21': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100}}

# %%
# Output
class PortfolioOutput:
    def __init__(self, portfolio, currency):
        self.portfolio = portfolio
        self.currency = currency

    def portfolio_daily_value(self):
        return self.portfolio.calculate_current_value(self.currency)

    def portfolio_net_cost(self):
        return self.portfolio.calculate_net()[0]

    def portfolio_total_quantity(self):
        return self.portfolio.calculate_net()[1]

    def portfolio_net_cost_per_unit(self):
        return self.portfolio.calculate_net()[2]

    def portfolio_net(self):
        return self.portfolio.calculate_net()

    def portfolio_daily_values_oneyear(self):
        return self.portfolio.assets_on_dates_oneyear()

    def portfolio_value_date_rs(self):
        input_dict = self.portfolio_daily_values_oneyear()
        values = self.portfolio.portfolio_value_for_dates(input_dict, "USD")
        return values

# %%
input_dic= P1.assets_on_dates_oneyear()

# %%
input_dic
# Out:
# {'2024-03-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-02-01': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-02': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-03': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-04': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-05': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-06': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-07': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-08': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-09': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-10': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-11': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-12': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-13': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-14': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-15': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-16': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-17': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-18': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-19': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-20': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-21': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-22': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-23': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-24': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-25': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-26': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-27': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-28': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-03-01': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-02': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-03': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-04': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-05': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-06': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-07': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-08': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-09': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-10': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-11': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-12': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-13': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-14': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-15': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-16': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-17': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-18': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-19': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-20': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-21': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-22': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100}}

# %%
P1.portfolio_value_for_dates(input_dic, "INR")
# Out:
# {}

# %%
def portfolio_value_for_dates(portfolio_dict, currency):
    stock_data = {}
    value_provider = PortfolioValueProvider()
    startDate = date.today() - timedelta(days=365)
    endDate = date.today()

    for date_str, stocks in portfolio_dict.items():
        date_obj = datetime.strptime(date_str, '%Y-%m-%d').date()  # Convert date string to date object
        for stock_name in stocks.keys():
            if stock_name not in stock_data:
                stock_data[stock_name] = value_provider.get_asset_values(stock_name, "Close", startDate, endDate)

    portfolio_value_by_dates = {}

    for date_str, stocks in portfolio_dict.items():
        # Convert date string to datetime object with time set to midnight
        date_obj = datetime.strptime(date_str, '%Y-%m-%d')
        date_key = date_obj.strftime('%Y-%m-%d %H:%M:%S')  # Format to match stock_history keys
        total_value = 0

        for stock_name, quantity in stocks.items():
            stock_history = stock_data[stock_name]

            if date_key in stock_history:
                stock_value = stock_history[date_key] * quantity
                total_value += stock_value

        if total_value > 0:
            portfolio_value_by_dates[date_str] = total_value
    return portfolio_value_by_dates

# %%
portfolio_value_for_dates(input_dic, "INR")
# Out:
# {'2024-03-26': 865762.0654296875,
#  '2024-03-27': 866142.9931640625,
#  '2024-03-28': 873699.1442871094,
#  '2024-04-01': 884139.599609375,
#  '2024-04-02': 884398.7231445312,
#  '2024-04-03': 885148.5827636719,
#  '2024-04-04': 897089.0649414062,
#  '2024-04-05': 899811.3439941406,
#  '2024-04-08': 899273.2104492188,
#  '2024-04-09': 896992.5903320312,
#  '2024-04-10': 896380.7775878906,
#  '2024-04-12': 889625.0671386719,
#  '2024-04-15': 875046.0327148438,
#  '2024-04-16': 877829.3408203125,
#  '2024-04-18': 873302.5122070312,
#  '2024-04-19': 880499.1003417969,
#  '2024-04-22': 881478.7060546875,
#  '2024-04-23': 884669.1003417969,
#  '2024-04-24': 882495.4040527344,
#  '2024-04-25': 878878.6181640625,
#  '2024-04-26': 875483.8305664062,
#  '2024-04-29': 882692.0422363281,
#  '2024-04-30': 878502.6965332031,
#  '2024-05-02': 882663.5668945312,
#  '2024-05-03': 877435.6787109375,
#  '2024-05-06': 888998.2263183594,
#  '2024-05-07': 908579.3359375,
#  '2024-05-08': 898362.8259277344,
#  '2024-05-09': 887695.3979492188,
#  '2024-05-10': 891424.1271972656,
#  '2024-05-13': 898088.7536621094,
#  '2024-05-14': 894526.2890625,
#  '2024-05-15': 885007.1655273438,
#  '2024-05-16': 895141.3208007812,
#  '2024-05-17': 888266.435546875,
#  '2024-05-21': 885022.2509765625,
#  '2024-05-22': 894566.1499023438,
#  '2024-05-23': 906946.0876464844,
#  '2024-05-24': 906854.6154785156,
#  '2024-05-27': 911112.1118164062,
#  '2024-05-28': 912831.38671875,
#  '2024-05-29': 902836.8188476562,
#  '2024-05-30': 896302.6086425781,
#  '2024-05-31': 891942.0617675781,
#  '2024-06-03': 905989.4848632812,
#  '2024-06-04': 910831.4880371094,
#  '2024-06-05': 943478.2751464844,
#  '2024-06-06': 942156.6577148438,
#  '2024-06-07': 953711.3513183594,
#  '2024-06-10': 947227.5427246094,
#  '2024-06-11': 946623.6169433594,
#  '2024-06-12': 943187.6477050781,
#  '2024-06-13': 940475.64453125,
#  '2024-06-14': 943387.9895019531,
#  '2024-06-18': 945387.6452636719,
#  '2024-06-19': 949239.0112304688,
#  '2024-06-20': 954583.6791992188,
#  '2024-06-21': 949400.2709960938,
#  '2024-06-24': 954470.8630371094,
#  '2024-06-25': 960855.3295898438,
#  '2024-06-26': 962208.8952636719,
#  '2024-06-27': 967869.2724609375,
#  '2024-06-28': 966867.939453125,
#  '2024-07-01': 981030.2124023438,
#  '2024-07-02': 984957.1545410156,
#  '2024-07-03': 993266.8298339844,
#  '2024-07-04': 986060.3698730469,
#  '2024-07-05': 978563.4240722656,
#  '2024-07-08': 980963.1396484375,
#  '2024-07-09': 984930.498046875,
#  '2024-07-10': 980429.3469238281,
#  '2024-07-11': 980909.8303222656,
#  '2024-07-12': 998376.4624023438,
#  '2024-07-15': 997172.4304199219,
#  '2024-07-16': 1007789.4091796875,
#  '2024-07-18': 1022575.4467773438,
#  '2024-07-19': 1018129.6215820312,
#  '2024-07-22': 1025211.2255859375,
#  '2024-07-23': 1026771.5686035156,
#  '2024-07-24': 1016994.8974609375,
#  '2024-07-25': 1019286.6589355469,
#  '2024-07-26': 1024390.7336425781,
#  '2024-07-29': 1021592.353515625,
#  '2024-07-30': 1019455.1611328125,
#  '2024-07-31': 1022819.4311523438,
#  '2024-08-01': 1029075.9936523438,
#  '2024-08-02': 1022039.7106933594,
#  '2024-08-05': 1009283.5668945312,
#  '2024-08-06': 1012344.55078125,
#  '2024-08-07': 1018006.1108398438,
#  '2024-08-08': 1019175.0,
#  '2024-08-09': 1027485.9448242188,
#  '2024-08-12': 1027097.0178222656,
#  '2024-08-13': 1014524.7900390625,
#  '2024-08-14': 1018482.255859375,
#  '2024-08-16': 1034603.2873535156,
#  '2024-08-19': 1038966.5844726562,
#  '2024-08-20': 1044788.5546875,
#  '2024-08-21': 1050717.4853515625,
#  '2024-08-22': 1049493.2543945312,
#  '2024-08-23': 1049288.7890625,
#  '2024-08-26': 1055390.5688476562,
#  '2024-08-27': 1045980.0659179688,
#  '2024-08-28': 1046403.6096191406,
#  '2024-08-29': 1049946.7260742188,
#  '2024-08-30': 1050558.7048339844,
#  '2024-09-02': 1048141.0986328125,
#  '2024-09-03': 1052588.8195800781,
#  '2024-09-04': 1059703.5668945312,
#  '2024-09-05': 1059199.2456054688,
#  '2024-09-06': 1055829.9584960938,
#  '2024-09-09': 1070719.4750976562,
#  '2024-09-10': 1071846.9055175781,
#  '2024-09-11': 1069339.6008300781,
#  '2024-09-12': 1084296.3586425781,
#  '2024-09-13': 1080898.8623046875,
#  '2024-09-16': 1070840.341796875,
#  '2024-09-17': 1071506.474609375,
#  '2024-09-18': 1066783.5009765625,
#  '2024-09-19': 1070983.0883789062,
#  '2024-09-20': 1087502.0483398438,
#  '2024-09-23': 1097903.9672851562,
#  '2024-09-24': 1087784.1284179688,
#  '2024-09-25': 1090394.1296386719,
#  '2024-09-26': 1097994.4970703125,
#  '2024-09-27': 1091589.8962402344,
#  '2024-09-30': 1084095.0390625,
#  '2024-10-01': 1078809.3627929688,
#  '2024-10-03': 1061259.53125,
#  '2024-10-04': 1050469.2443847656,
#  '2024-10-07': 1038895.5493164062,
#  '2024-10-08': 1043386.4868164062,
#  '2024-10-09': 1032256.6687011719,
#  '2024-10-10': 1034224.0661621094,
#  '2024-10-11': 1031430.0537109375,
#  '2024-10-14': 1038760.9069824219,
#  '2024-10-15': 1035754.9645996094,
#  '2024-10-16': 1037521.9360351562,
#  '2024-10-17': 1026169.4055175781,
#  '2024-10-18': 1026196.1462402344,
#  '2024-10-21': 1029926.7407226562,
#  '2024-10-22': 1019850.9594726562,
#  '2024-10-23': 1023971.4575195312,
#  '2024-10-24': 1001926.9152832031,
#  '2024-10-25': 1003378.4680175781,
#  '2024-10-28': 1011763.8989257812,
#  '2024-10-29': 1010256.9909667969,
#  '2024-10-30': 1008449.0124511719,
#  '2024-10-31': 997933.5375976562,
#  '2024-11-01': 1000524.9169921875,
#  '2024-11-04': 992023.3508300781,
#  '2024-11-05': 1000622.5329589844,
#  '2024-11-06': 1009461.4794921875,
#  '2024-11-07': 1004106.9140625,
#  '2024-11-08': 1009981.4501953125,
#  '2024-11-11': 1012819.1137695312,
#  '2024-11-12': 998274.2456054688,
#  '2024-11-13': 987882.4621582031,
#  '2024-11-14': 977700.1000976562,
#  '2024-11-18': 977729.6252441406,
#  '2024-11-19': 984158.3081054688,
#  '2024-11-21': 980808.5327148438,
#  '2024-11-22': 1001609.0222167969,
#  '2024-11-25': 1018222.4670410156,
#  '2024-11-26': 1021627.6245117188,
#  '2024-11-27': 1026565.9643554688,
#  '2024-11-28': 1013609.4836425781,
#  '2024-11-29': 1020333.8012695312,
#  '2024-12-02': 1019443.4204101562,
#  '2024-12-03': 1025937.7563476562,
#  '2024-12-04': 1032420.3674316406,
#  '2024-12-05': 1044272.236328125,
#  '2024-12-06': 1039669.8718261719,
#  '2024-12-09': 1029595.9252929688,
#  '2024-12-10': 1027874.2150878906,
#  '2024-12-11': 1026953.4704589844,
#  '2024-12-12': 1018548.525390625,
#  '2024-12-13': 1029136.8359375,
#  '2024-12-16': 1021289.6923828125,
#  '2024-12-17': 1009065.5688476562,
#  '2024-12-18': 1004929.8022460938,
#  '2024-12-19': 996861.1645507812,
#  '2024-12-20': 981543.5986328125,
#  '2024-12-23': 986566.8286132812,
#  '2024-12-24': 986962.8112792969,
#  '2024-12-26': 984179.8095703125,
#  '2024-12-27': 986779.9243164062,
#  '2024-12-30': 982985.7604980469,
#  '2024-12-31': 975447.9211425781,
#  '2025-01-01': 978926.416015625,
#  '2025-01-02': 992303.8647460938,
#  '2025-01-03': 984695.6616210938,
#  '2025-01-06': 971201.3720703125,
#  '2025-01-07': 969837.4011230469,
#  '2025-01-08': 972710.9790039062,
#  '2025-01-09': 969045.390625,
#  '2025-01-10': 980907.5354003906,
#  '2025-01-13': 978354.4018554688,
#  '2025-01-14': 964878.1677246094,
#  '2025-01-15': 966145.3332519531,
#  '2025-01-16': 960876.4978027344,
#  '2025-01-17': 955113.4887695312,
#  '2025-01-20': 953984.4946289062,
#  '2025-01-21': 948488.0102539062,
#  '2025-01-22': 963119.0063476562,
#  '2025-01-23': 958852.0080566406,
#  '2025-01-24': 963118.5302734375}

# %%
input_dic
# Out:
# {'2024-03-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-03-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-04-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-05-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-06-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-07-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-08-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-09-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-10-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-11-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2024-12-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-01': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-02': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-03': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-04': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-05': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-06': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-07': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-08': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-09': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-10': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-11': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-12': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-13': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-14': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-15': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-16': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-17': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-18': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-19': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-20': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-21': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-22': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-23': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-24': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-25': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-26': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-27': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-28': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-29': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-30': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-01-31': {'BBTC.NS': 10,
#   'HDFCBANK.NS': 190,
#   'HINDUNILVR.NS': 160,
#   'TCS.NS': 60},
#  '2025-02-01': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-02': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-03': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-04': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-05': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-06': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-07': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-08': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-09': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-10': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-11': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-12': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-13': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-14': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-15': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-16': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-17': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-18': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-19': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-20': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-21': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-22': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-23': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-24': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-25': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-26': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-27': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-02-28': {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  '2025-03-01': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-02': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-03': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  '2025-03-04': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-05': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-06': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-07': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-08': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-09': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-10': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  '2025-03-11': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-12': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-13': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-14': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-15': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-16': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-17': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-18': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-19': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-20': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-21': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  '2025-03-22': {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100}}

# %%
list(input_dic.keys())
# Out:
# ['2024-03-22',
#  '2024-03-23',
#  '2024-03-24',
#  '2024-03-25',
#  '2024-03-26',
#  '2024-03-27',
#  '2024-03-28',
#  '2024-03-29',
#  '2024-03-30',
#  '2024-03-31',
#  '2024-04-01',
#  '2024-04-02',
#  '2024-04-03',
#  '2024-04-04',
#  '2024-04-05',
#  '2024-04-06',
#  '2024-04-07',
#  '2024-04-08',
#  '2024-04-09',
#  '2024-04-10',
#  '2024-04-11',
#  '2024-04-12',
#  '2024-04-13',
#  '2024-04-14',
#  '2024-04-15',
#  '2024-04-16',
#  '2024-04-17',
#  '2024-04-18',
#  '2024-04-19',
#  '2024-04-20',
#  '2024-04-21',
#  '2024-04-22',
#  '2024-04-23',
#  '2024-04-24',
#  '2024-04-25',
#  '2024-04-26',
#  '2024-04-27',
#  '2024-04-28',
#  '2024-04-29',
#  '2024-04-30',
#  '2024-05-01',
#  '2024-05-02',
#  '2024-05-03',
#  '2024-05-04',
#  '2024-05-05',
#  '2024-05-06',
#  '2024-05-07',
#  '2024-05-08',
#  '2024-05-09',
#  '2024-05-10',
#  '2024-05-11',
#  '2024-05-12',
#  '2024-05-13',
#  '2024-05-14',
#  '2024-05-15',
#  '2024-05-16',
#  '2024-05-17',
#  '2024-05-18',
#  '2024-05-19',
#  '2024-05-20',
#  '2024-05-21',
#  '2024-05-22',
#  '2024-05-23',
#  '2024-05-24',
#  '2024-05-25',
#  '2024-05-26',
#  '2024-05-27',
#  '2024-05-28',
#  '2024-05-29',
#  '2024-05-30',
#  '2024-05-31',
#  '2024-06-01',
#  '2024-06-02',
#  '2024-06-03',
#  '2024-06-04',
#  '2024-06-05',
#  '2024-06-06',
#  '2024-06-07',
#  '2024-06-08',
#  '2024-06-09',
#  '2024-06-10',
#  '2024-06-11',
#  '2024-06-12',
#  '2024-06-13',
#  '2024-06-14',
#  '2024-06-15',
#  '2024-06-16',
#  '2024-06-17',
#  '2024-06-18',
#  '2024-06-19',
#  '2024-06-20',
#  '2024-06-21',
#  '2024-06-22',
#  '2024-06-23',
#  '2024-06-24',
#  '2024-06-25',
#  '2024-06-26',
#  '2024-06-27',
#  '2024-06-28',
#  '2024-06-29',
#  '2024-06-30',
#  '2024-07-01',
#  '2024-07-02',
#  '2024-07-03',
#  '2024-07-04',
#  '2024-07-05',
#  '2024-07-06',
#  '2024-07-07',
#  '2024-07-08',
#  '2024-07-09',
#  '2024-07-10',
#  '2024-07-11',
#  '2024-07-12',
#  '2024-07-13',
#  '2024-07-14',
#  '2024-07-15',
#  '2024-07-16',
#  '2024-07-17',
#  '2024-07-18',
#  '2024-07-19',
#  '2024-07-20',
#  '2024-07-21',
#  '2024-07-22',
#  '2024-07-23',
#  '2024-07-24',
#  '2024-07-25',
#  '2024-07-26',
#  '2024-07-27',
#  '2024-07-28',
#  '2024-07-29',
#  '2024-07-30',
#  '2024-07-31',
#  '2024-08-01',
#  '2024-08-02',
#  '2024-08-03',
#  '2024-08-04',
#  '2024-08-05',
#  '2024-08-06',
#  '2024-08-07',
#  '2024-08-08',
#  '2024-08-09',
#  '2024-08-10',
#  '2024-08-11',
#  '2024-08-12',
#  '2024-08-13',
#  '2024-08-14',
#  '2024-08-15',
#  '2024-08-16',
#  '2024-08-17',
#  '2024-08-18',
#  '2024-08-19',
#  '2024-08-20',
#  '2024-08-21',
#  '2024-08-22',
#  '2024-08-23',
#  '2024-08-24',
#  '2024-08-25',
#  '2024-08-26',
#  '2024-08-27',
#  '2024-08-28',
#  '2024-08-29',
#  '2024-08-30',
#  '2024-08-31',
#  '2024-09-01',
#  '2024-09-02',
#  '2024-09-03',
#  '2024-09-04',
#  '2024-09-05',
#  '2024-09-06',
#  '2024-09-07',
#  '2024-09-08',
#  '2024-09-09',
#  '2024-09-10',
#  '2024-09-11',
#  '2024-09-12',
#  '2024-09-13',
#  '2024-09-14',
#  '2024-09-15',
#  '2024-09-16',
#  '2024-09-17',
#  '2024-09-18',
#  '2024-09-19',
#  '2024-09-20',
#  '2024-09-21',
#  '2024-09-22',
#  '2024-09-23',
#  '2024-09-24',
#  '2024-09-25',
#  '2024-09-26',
#  '2024-09-27',
#  '2024-09-28',
#  '2024-09-29',
#  '2024-09-30',
#  '2024-10-01',
#  '2024-10-02',
#  '2024-10-03',
#  '2024-10-04',
#  '2024-10-05',
#  '2024-10-06',
#  '2024-10-07',
#  '2024-10-08',
#  '2024-10-09',
#  '2024-10-10',
#  '2024-10-11',
#  '2024-10-12',
#  '2024-10-13',
#  '2024-10-14',
#  '2024-10-15',
#  '2024-10-16',
#  '2024-10-17',
#  '2024-10-18',
#  '2024-10-19',
#  '2024-10-20',
#  '2024-10-21',
#  '2024-10-22',
#  '2024-10-23',
#  '2024-10-24',
#  '2024-10-25',
#  '2024-10-26',
#  '2024-10-27',
#  '2024-10-28',
#  '2024-10-29',
#  '2024-10-30',
#  '2024-10-31',
#  '2024-11-01',
#  '2024-11-02',
#  '2024-11-03',
#  '2024-11-04',
#  '2024-11-05',
#  '2024-11-06',
#  '2024-11-07',
#  '2024-11-08',
#  '2024-11-09',
#  '2024-11-10',
#  '2024-11-11',
#  '2024-11-12',
#  '2024-11-13',
#  '2024-11-14',
#  '2024-11-15',
#  '2024-11-16',
#  '2024-11-17',
#  '2024-11-18',
#  '2024-11-19',
#  '2024-11-20',
#  '2024-11-21',
#  '2024-11-22',
#  '2024-11-23',
#  '2024-11-24',
#  '2024-11-25',
#  '2024-11-26',
#  '2024-11-27',
#  '2024-11-28',
#  '2024-11-29',
#  '2024-11-30',
#  '2024-12-01',
#  '2024-12-02',
#  '2024-12-03',
#  '2024-12-04',
#  '2024-12-05',
#  '2024-12-06',
#  '2024-12-07',
#  '2024-12-08',
#  '2024-12-09',
#  '2024-12-10',
#  '2024-12-11',
#  '2024-12-12',
#  '2024-12-13',
#  '2024-12-14',
#  '2024-12-15',
#  '2024-12-16',
#  '2024-12-17',
#  '2024-12-18',
#  '2024-12-19',
#  '2024-12-20',
#  '2024-12-21',
#  '2024-12-22',
#  '2024-12-23',
#  '2024-12-24',
#  '2024-12-25',
#  '2024-12-26',
#  '2024-12-27',
#  '2024-12-28',
#  '2024-12-29',
#  '2024-12-30',
#  '2024-12-31',
#  '2025-01-01',
#  '2025-01-02',
#  '2025-01-03',
#  '2025-01-04',
#  '2025-01-05',
#  '2025-01-06',
#  '2025-01-07',
#  '2025-01-08',
#  '2025-01-09',
#  '2025-01-10',
#  '2025-01-11',
#  '2025-01-12',
#  '2025-01-13',
#  '2025-01-14',
#  '2025-01-15',
#  '2025-01-16',
#  '2025-01-17',
#  '2025-01-18',
#  '2025-01-19',
#  '2025-01-20',
#  '2025-01-21',
#  '2025-01-22',
#  '2025-01-23',
#  '2025-01-24',
#  '2025-01-25',
#  '2025-01-26',
#  '2025-01-27',
#  '2025-01-28',
#  '2025-01-29',
#  '2025-01-30',
#  '2025-01-31',
#  '2025-02-01',
#  '2025-02-02',
#  '2025-02-03',
#  '2025-02-04',
#  '2025-02-05',
#  '2025-02-06',
#  '2025-02-07',
#  '2025-02-08',
#  '2025-02-09',
#  '2025-02-10',
#  '2025-02-11',
#  '2025-02-12',
#  '2025-02-13',
#  '2025-02-14',
#  '2025-02-15',
#  '2025-02-16',
#  '2025-02-17',
#  '2025-02-18',
#  '2025-02-19',
#  '2025-02-20',
#  '2025-02-21',
#  '2025-02-22',
#  '2025-02-23',
#  '2025-02-24',
#  '2025-02-25',
#  '2025-02-26',
#  '2025-02-27',
#  '2025-02-28',
#  '2025-03-01',
#  '2025-03-02',
#  '2025-03-03',
#  '2025-03-04',
#  '2025-03-05',
#  '2025-03-06',
#  '2025-03-07',
#  '2025-03-08',
#  '2025-03-09',
#  '2025-03-10',
#  '2025-03-11',
#  '2025-03-12',
#  '2025-03-13',
#  '2025-03-14',
#  '2025-03-15',
#  '2025-03-16',
#  '2025-03-17',
#  '2025-03-18',
#  '2025-03-19',
#  '2025-03-20',
#  '2025-03-21',
#  '2025-03-22']

# %%
list(input_dic.values())
# Out:
# [{'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'BBTC.NS': 10, 'HDFCBANK.NS': 190, 'HINDUNILVR.NS': 160, 'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'HDFCBANK.NS': 190,
#   'TCS.NS': 60},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20,
#   'TCS.NS': 60},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 20},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100},
#  {'HDFCBANK.NS': 200,
#   'HINDUNILVR.NS': 180,
#   'TCS.NS': 90,
#   'BBTC.NS': 10,
#   'BALKRISIND.NS': 100}]

# %%
startDate
# Out:
# datetime.date(2024, 3, 22)

# %%
endDate
# Out:
# datetime.date(2025, 3, 22)

# %%
stock_data_1 = PortfolioValueProvider().get_asset_values("BBTC.NS","Close", startDate, endDate)

# %%
len(stock_data_1)
# Out:
# 208

# %%
len(list(input_dic.keys()))
# Out:
# 366

# %%
stock_data_1
# Out:
# {'2024-03-22 00:00:00': 1573.9544677734375,
#  '2024-03-26 00:00:00': 1572.1552734375,
#  '2024-03-27 00:00:00': 1544.6700439453125,
#  '2024-03-28 00:00:00': 1566.908203125,
#  '2024-04-01 00:00:00': 1607.986083984375,
#  '2024-04-02 00:00:00': 1635.271484375,
#  '2024-04-03 00:00:00': 1633.7222900390625,
#  '2024-04-04 00:00:00': 1651.412841796875,
#  '2024-04-05 00:00:00': 1622.8780517578125,
#  '2024-04-08 00:00:00': 1632.4229736328125,
#  '2024-04-09 00:00:00': 1597.341796875,
#  '2024-04-10 00:00:00': 1590.7952880859375,
#  '2024-04-12 00:00:00': 1593.69384765625,
#  '2024-04-15 00:00:00': 1550.0672607421875,
#  '2024-04-16 00:00:00': 1538.023681640625,
#  '2024-04-18 00:00:00': 1516.6351318359375,
#  '2024-04-19 00:00:00': 1496.8458251953125,
#  '2024-04-22 00:00:00': 1569.456787109375,
#  '2024-04-23 00:00:00': 1579.601318359375,
#  '2024-04-24 00:00:00': 1582.99951171875,
#  '2024-04-25 00:00:00': 1578.05224609375,
#  '2024-04-26 00:00:00': 1568.2574462890625,
#  '2024-04-29 00:00:00': 1576.453125,
#  '2024-04-30 00:00:00': 1558.11279296875,
#  '2024-05-02 00:00:00': 1559.7120361328125,
#  '2024-05-03 00:00:00': 1537.723876953125,
#  '2024-05-06 00:00:00': 1559.6619873046875,
#  '2024-05-07 00:00:00': 1540.1724853515625,
#  '2024-05-08 00:00:00': 1576.1031494140625,
#  '2024-05-09 00:00:00': 1510.338623046875,
#  '2024-05-10 00:00:00': 1504.841552734375,
#  '2024-05-13 00:00:00': 1552.8656005859375,
#  '2024-05-14 00:00:00': 1538.323486328125,
#  '2024-05-15 00:00:00': 1551.066650390625,
#  '2024-05-16 00:00:00': 1548.718017578125,
#  '2024-05-17 00:00:00': 1546.1693115234375,
#  '2024-05-21 00:00:00': 1557.563232421875,
#  '2024-05-22 00:00:00': 1547.06884765625,
#  '2024-05-23 00:00:00': 1538.173583984375,
#  '2024-05-24 00:00:00': 1535.7249755859375,
#  '2024-05-27 00:00:00': 1532.7265625,
#  '2024-05-28 00:00:00': 1513.3369140625,
#  '2024-05-29 00:00:00': 1507.5400390625,
#  '2024-05-30 00:00:00': 1479.30517578125,
#  '2024-05-31 00:00:00': 1466.8118896484375,
#  '2024-06-03 00:00:00': 1485.40185546875,
#  '2024-06-04 00:00:00': 1373.26220703125,
#  '2024-06-05 00:00:00': 1466.1622314453125,
#  '2024-06-06 00:00:00': 1522.6318359375,
#  '2024-06-07 00:00:00': 1595.093017578125,
#  '2024-06-10 00:00:00': 1582.1500244140625,
#  '2024-06-11 00:00:00': 1636.6207275390625,
#  '2024-06-12 00:00:00': 1673.600830078125,
#  '2024-06-13 00:00:00': 1651.8125,
#  '2024-06-14 00:00:00': 1650.263427734375,
#  '2024-06-18 00:00:00': 1640.5186767578125,
#  '2024-06-19 00:00:00': 1620.6793212890625,
#  '2024-06-20 00:00:00': 1621.1290283203125,
#  '2024-06-21 00:00:00': 1682.995849609375,
#  '2024-06-24 00:00:00': 2013.318359375,
#  '2024-06-25 00:00:00': 1942.1065673828125,
#  '2024-06-26 00:00:00': 1947.4036865234375,
#  '2024-06-27 00:00:00': 1884.8873291015625,
#  '2024-06-28 00:00:00': 2024.412353515625,
#  '2024-07-01 00:00:00': 2082.13134765625,
#  '2024-07-02 00:00:00': 2076.63427734375,
#  '2024-07-03 00:00:00': 2093.72509765625,
#  '2024-07-04 00:00:00': 2059.24365234375,
#  '2024-07-05 00:00:00': 2052.447265625,
#  '2024-07-08 00:00:00': 2005.6224365234375,
#  '2024-07-09 00:00:00': 2378.572265625,
#  '2024-07-10 00:00:00': 2257.38720703125,
#  '2024-07-11 00:00:00': 2324.051513671875,
#  '2024-07-12 00:00:00': 2291.56884765625,
#  '2024-07-15 00:00:00': 2301.513427734375,
#  '2024-07-16 00:00:00': 2266.68212890625,
#  '2024-07-18 00:00:00': 2226.5537109375,
#  '2024-07-19 00:00:00': 2124.95849609375,
#  '2024-07-22 00:00:00': 2120.960693359375,
#  '2024-07-23 00:00:00': 2151.444091796875,
#  '2024-07-24 00:00:00': 2208.813232421875,
#  '2024-07-25 00:00:00': 2259.486083984375,
#  '2024-07-26 00:00:00': 2288.870361328125,
#  '2024-07-29 00:00:00': 2289.469970703125,
#  '2024-07-30 00:00:00': 2292.218505859375,
#  '2024-07-31 00:00:00': 2278.325927734375,
#  '2024-08-01 00:00:00': 2238.09765625,
#  '2024-08-02 00:00:00': 2195.37060546875,
#  '2024-08-05 00:00:00': 2136.552001953125,
#  '2024-08-06 00:00:00': 2078.433349609375,
#  '2024-08-07 00:00:00': 2141.849365234375,
#  '2024-08-08 00:00:00': 2233.449951171875,
#  '2024-08-09 00:00:00': 2363.35009765625,
#  '2024-08-12 00:00:00': 2310.10009765625,
#  '2024-08-13 00:00:00': 2242.550048828125,
#  '2024-08-14 00:00:00': 2272.300048828125,
#  '2024-08-16 00:00:00': 2283.85009765625,
#  '2024-08-19 00:00:00': 2379.89990234375,
#  '2024-08-20 00:00:00': 2510.949951171875,
#  '2024-08-21 00:00:00': 2521.699951171875,
#  '2024-08-22 00:00:00': 2564.85009765625,
#  '2024-08-23 00:00:00': 2527.300048828125,
#  '2024-08-26 00:00:00': 2535.75,
#  '2024-08-27 00:00:00': 2532.699951171875,
#  '2024-08-28 00:00:00': 2574.89990234375,
#  '2024-08-29 00:00:00': 2534.25,
#  '2024-08-30 00:00:00': 2491.85009765625,
#  '2024-09-02 00:00:00': 2458.300048828125,
#  '2024-09-03 00:00:00': 2673.75,
#  '2024-09-04 00:00:00': 2750.10009765625,
#  '2024-09-05 00:00:00': 2694.64990234375,
#  '2024-09-06 00:00:00': 2625.89990234375,
#  '2024-09-09 00:00:00': 2656.050048828125,
#  '2024-09-10 00:00:00': 2717.25,
#  '2024-09-11 00:00:00': 2670.800048828125,
#  '2024-09-12 00:00:00': 2673.5,
#  '2024-09-13 00:00:00': 2690.550048828125,
#  '2024-09-16 00:00:00': 2694.949951171875,
#  '2024-09-17 00:00:00': 2745.800048828125,
#  '2024-09-18 00:00:00': 2694.449951171875,
#  '2024-09-19 00:00:00': 2580.550048828125,
#  '2024-09-20 00:00:00': 2628.89990234375,
#  '2024-09-23 00:00:00': 2601.64990234375,
#  '2024-09-24 00:00:00': 2659.25,
#  '2024-09-25 00:00:00': 2715.199951171875,
#  '2024-09-26 00:00:00': 2694.550048828125,
#  '2024-09-27 00:00:00': 2858.89990234375,
#  '2024-09-30 00:00:00': 2867.550048828125,
#  '2024-10-01 00:00:00': 2884.89990234375,
#  '2024-10-03 00:00:00': 2783.5,
#  '2024-10-04 00:00:00': 2761.449951171875,
#  '2024-10-07 00:00:00': 2482.85009765625,
#  '2024-10-08 00:00:00': 2649.89990234375,
#  '2024-10-09 00:00:00': 2673.25,
#  '2024-10-10 00:00:00': 2693.89990234375,
#  '2024-10-11 00:00:00': 2643.85009765625,
#  '2024-10-14 00:00:00': 2652.949951171875,
#  '2024-10-15 00:00:00': 2668.800048828125,
#  '2024-10-16 00:00:00': 2680.85009765625,
#  '2024-10-17 00:00:00': 2646.949951171875,
#  '2024-10-18 00:00:00': 2683.800048828125,
#  '2024-10-21 00:00:00': 2800.60009765625,
#  '2024-10-22 00:00:00': 2635.89990234375,
#  '2024-10-23 00:00:00': 2697.39990234375,
#  '2024-10-24 00:00:00': 2797.050048828125,
#  '2024-10-25 00:00:00': 2637.449951171875,
#  '2024-10-28 00:00:00': 2690.5,
#  '2024-10-29 00:00:00': 2746.449951171875,
#  '2024-10-30 00:00:00': 2720.800048828125,
#  '2024-10-31 00:00:00': 2769.39990234375,
#  '2024-11-01 00:00:00': 2756.449951171875,
#  '2024-11-04 00:00:00': 2669.5,
#  '2024-11-05 00:00:00': 2710.050048828125,
#  '2024-11-06 00:00:00': 2806.35009765625,
#  '2024-11-07 00:00:00': 2772.050048828125,
#  '2024-11-08 00:00:00': 2717.550048828125,
#  '2024-11-11 00:00:00': 2733.10009765625,
#  '2024-11-12 00:00:00': 2673.10009765625,
#  '2024-11-13 00:00:00': 2560.5,
#  '2024-11-14 00:00:00': 2564.300048828125,
#  '2024-11-18 00:00:00': 2550.0,
#  '2024-11-19 00:00:00': 2567.800048828125,
#  '2024-11-21 00:00:00': 2494.25,
#  '2024-11-22 00:00:00': 2463.449951171875,
#  '2024-11-25 00:00:00': 2523.60009765625,
#  '2024-11-26 00:00:00': 2516.0,
#  '2024-11-27 00:00:00': 2499.0,
#  '2024-11-28 00:00:00': 2487.050048828125,
#  '2024-11-29 00:00:00': 2405.85009765625,
#  '2024-12-02 00:00:00': 2389.75,
#  '2024-12-03 00:00:00': 2413.35009765625,
#  '2024-12-04 00:00:00': 2403.85009765625,
#  '2024-12-05 00:00:00': 2343.75,
#  '2024-12-06 00:00:00': 2355.449951171875,
#  '2024-12-09 00:00:00': 2368.199951171875,
#  '2024-12-10 00:00:00': 2403.85009765625,
#  '2024-12-11 00:00:00': 2373.300048828125,
#  '2024-12-12 00:00:00': 2343.75,
#  '2024-12-13 00:00:00': 2329.25,
#  '2024-12-16 00:00:00': 2403.550048828125,
#  '2024-12-17 00:00:00': 2353.550048828125,
#  '2024-12-18 00:00:00': 2317.39990234375,
#  '2024-12-19 00:00:00': 2281.550048828125,
#  '2024-12-20 00:00:00': 2191.14990234375,
#  '2024-12-23 00:00:00': 2124.800048828125,
#  '2024-12-24 00:00:00': 2146.199951171875,
#  '2024-12-26 00:00:00': 2114.60009765625,
#  '2024-12-27 00:00:00': 2121.550048828125,
#  '2024-12-30 00:00:00': 2129.0,
#  '2024-12-31 00:00:00': 2120.64990234375,
#  '2025-01-01 00:00:00': 2250.75,
#  '2025-01-02 00:00:00': 2234.199951171875,
#  '2025-01-03 00:00:00': 2193.85009765625,
#  '2025-01-06 00:00:00': 2089.85009765625,
#  '2025-01-07 00:00:00': 2064.0,
#  '2025-01-08 00:00:00': 2071.60009765625,
#  '2025-01-09 00:00:00': 2074.449951171875,
#  '2025-01-10 00:00:00': 2006.6500244140625,
#  '2025-01-13 00:00:00': 1947.9000244140625,
#  '2025-01-14 00:00:00': 1977.300048828125,
#  '2025-01-15 00:00:00': 1991.5999755859375,
#  '2025-01-16 00:00:00': 2000.9000244140625,
#  '2025-01-17 00:00:00': 2003.300048828125,
#  '2025-01-20 00:00:00': 2034.699951171875,
#  '2025-01-21 00:00:00': 1980.0999755859375,
#  '2025-01-22 00:00:00': 2230.14990234375,
#  '2025-01-23 00:00:00': 2232.199951171875,
#  '2025-01-24 00:00:00': 2161.949951171875}

# %%
get_asset_values("HDFCBANK", "India", startDate, endDate)
# Out:
# $HDFCBANK.NS: possibly delisted; no price data found  (1d 2024-03-22 -> 2025-03-22)
# []

# %%
tickerData = yf.Tickers("BBTC.NS")

# %%
yf.__version__
# Out:
# '0.2.55'

# %%
import yfinance as yf
